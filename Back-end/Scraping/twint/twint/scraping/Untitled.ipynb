# %%
import pandas as pd
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
# Configure
c = twint.Config()
c.Search = "abortips"
c.User_full = True
c.Profile_full = True
c.Retweets = True
c.Pandas = True
c.Store_json = True
c.Output = "salida.json"
# Run
twint.run.Search(c)
# Out:
# 1068487200604594177 2018-11-30 07:49:34 -05 <RoyValle8> HAHAJAHA a la orden abortips♡
# 1006359058717212673 2018-06-11 21:14:31 -05 <JulitaMachado> si la Dani hubiese abortado te ahorrarias ese tweet. #AborTips
# 1004124680847069184 2018-06-05 17:15:54 -05 <Ilasd> Colgalo de la tirita de arriba así no se te llena de mugre #abortips
# 1004055447060426752 2018-06-05 12:40:47 -05 <_alepardo98> Abortips!
# 1002280419595833344 2018-05-31 15:07:28 -05 <RevBeladas> #AborTips El aborto no es genocidio Genocidio fueron lxs 30.000 y te chuparon un huevo Tincho. #YoVotoAbortoLegal #AbortoLegalYa
# 1002278640003010560 2018-05-31 15:00:23 -05 <RevBeladas> #AborTips Contanos más hombre cis de lo que se siente al abortar y al parir. Tiene mucha lógica siendo dos momentos que en tu yuta vida vas a vivir. #YoVotoAbortoLegal #AbortoLegalYa
# ...

# %%
# Configure
tweets = []
Tweets_df = None
c = twint.Config()
c.Search = "https://twitter.com/DanielaLopezB18/status/1285686176632967168"
c.Retweets = True
c.Pandas = True
c.Store_object = True
c.Store_object_tweets_list = tweets
Tweets_df = twint.storage.panda.Tweets_df
# Run
twint.run.Search(c)
# Out:
# 1285689491202736128 2020-07-21 16:33:56 -05 <djbautista10> [tweet for testing ] https://twitter.com/DanielaLopezB18/status/1285686176632967168 …

# %%
pd.set_option('max_colwidth', 4000)
pd.set_option('max_columns', 4000)
Tweets_df
# Out:
#                     id      conversation_id     created_at  \
# 0  1285689491202736128  1285689491202736128  1595367236000
#
#                   date timezone place  \
# 0  2020-07-21 16:33:56      -05
#
#                                                                                    tweet  \
# 0  [tweet for testing ] https://twitter.com/DanielaLopezB18/status/1285686176632967168 …
#
#   hashtags cashtags              user_id          user_id_str      username  \
# 0       []       []  1167137190259888129  1167137190259888129  djbautista10
#
#              name  day hour  \
# 0  David Bautista    2   16
#
#                                                           link  retweet  \
# 0  https://twitter.com/djbautista10/status/1285689491202736128    False
#
#    nlikes  nreplies  nretweets  \
# 0       0         0          1
#
#                                                         quote_url  \
# 0  https://twitter.com/DanielaLopezB18/status/1285686176632967168
#
# ...

# %%
tweets[0].tweet
# Out:
# '[tweet for testing ] https://twitter.com/DanielaLopezB18/status/1285686176632967168\xa0…'

# %%
import inspect
inspect.getmembers(tweets[0])
# Out:
# [('__class__', twint.tweet.tweet),
#  ('__delattr__',
#   <method-wrapper '__delattr__' of tweet object at 0x1180055d0>),
#  ('__dict__',
#   {'id': 1285689491202736128,
#    'id_str': '1285689491202736128',
#    'conversation_id': '1285689491202736128',
#    'datetime': 1595367236000,
#    'datestamp': '2020-07-21',
#    'timestamp': '16:33:56',
#    'user_id': 1167137190259888129,
#    'user_id_str': '1167137190259888129',
#    'username': 'djbautista10',
#    'name': 'David Bautista',
#    'place': '',
#    'timezone': '-05',
#    'mentions': [],
#    'urls': ['https://twitter.com/DanielaLopezB18/status/1285686176632967168'],
#    'photos': [],
#    'video': 0,
#    'tweet': '[tweet for testing ] https://twitter.com/DanielaLopezB18/status/1285686176632967168\xa0…',
#    'hashtags': [],
#    'cashtags': [],
#    'replies_count': '0',
#    'retweets_count': '1',
#    'likes_count': '0',
#    'link': 'https://twitter.com/djbautista10/status/1285689491202736128',
# ...
