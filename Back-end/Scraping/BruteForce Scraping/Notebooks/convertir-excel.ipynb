# %%
import pandas as pd

# %%
df = pd.read_excel('RED SEMÁNTICA - SMDT.xlsx', sheet_name='sinonimos')

# %%
df
# Out:
#     infertilidad         aborto            efectiva pastillas  \
# 0        esteril        abortar            funciono    pastas
# 1      sin hijos         aborte            funciona  tabletas
# 2         inutil      abortamos              eficaz       NaN
# 3    esterilidad  perdi el bebe           veridico        NaN
# 4   infecundidad   interrupción         efectividad       NaN
# 5     impotencia        perdida               sirve       NaN
# 6            NaN   abortamiento            no sirve       NaN
# 7            NaN         perder       a veces sirve       NaN
# 8            NaN          matar  no es muy efectivo       NaN
# 9            NaN            NaN              seguro       NaN
# 10           NaN            NaN        no es seguro       NaN
# 11           NaN            NaN              riesgo       NaN
# 12           NaN            NaN            riesgoso       NaN
# 13           NaN            NaN       funcionalidad       NaN
#
# ...

# %%
headers=list(df)

# %%
{header:df[header].dropna().to_list() for header in headers}
# Out:
# {'infertilidad': ['esteril',
#   'sin hijos',
#   'inutil',
#   'esterilidad',
#   'infecundidad',
#   'impotencia'],
#  'aborto': ['abortar',
#   'aborte',
#   'abortamos',
#   'perdi el bebe',
#   'interrupción',
#   'perdida',
#   'abortamiento',
#   'perder',
#   'matar'],
#  'efectiva': ['funciono',
#   'funciona',
#   'eficaz',
#   'veridico ',
#   'efectividad',
#   'sirve',
#   'no sirve',
#   'a veces sirve',
#   'no es muy efectivo',
#   'seguro',
#   'no es seguro',
#   'riesgo',
#   'riesgoso',
#   'funcionalidad'],
#  'pastillas': ['pastas', 'tabletas'],
#  'postday': ['al dia siguiente',
#   'al acto',
#   'después',
#   'un día después',
#   'del día despúes',
#   'día'],
#  'hormonas': [],
#  'embarazo': ['bendicion',
#   'preñaron',
#   'preñada',
#   'gol',
#   'piñata',
#   'encinta',
#   'premiaron '],
#  'boli': ['helao', 'helado'],
#  'bolsa': ['bolsita'],
#  'alergia': ['pica', 'roncha'],
#  'latex': ['caucho'],
#  'condon': ['gorrito',
#   'chupito',
# ...
