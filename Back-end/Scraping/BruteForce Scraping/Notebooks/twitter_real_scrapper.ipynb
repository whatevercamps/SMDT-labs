# %%
import sys
import pandas as pd
import json

# %%
from twitterscraper import query_tweets

# %%
list_of_tweets = query_tweets("Trump OR Clinton", 10)

# %%
for tweet in query_tweets("Trump OR Clinton", 10):
    print(tweet)
# Out:
# INFO: queries: ['Trump OR Clinton since:2006-03-21 until:2006-11-26', 'Trump OR Clinton since:2006-11-26 until:2007-08-04', 'Trump OR Clinton since:2007-08-04 until:2008-04-11', 'Trump OR Clinton since:2008-04-11 until:2008-12-18', 'Trump OR Clinton since:2008-12-18 until:2009-08-26', 'Trump OR Clinton since:2009-08-26 until:2010-05-04', 'Trump OR Clinton since:2010-05-04 until:2011-01-10', 'Trump OR Clinton since:2011-01-10 until:2011-09-18', 'Trump OR Clinton since:2011-09-18 until:2012-05-26', 'Trump OR Clinton since:2012-05-26 until:2013-02-01', 'Trump OR Clinton since:2013-02-01 until:2013-10-10', 'Trump OR Clinton since:2013-10-10 until:2014-06-18', 'Trump OR Clinton since:2014-06-18 until:2015-02-24', 'Trump OR Clinton since:2015-02-24 until:2015-11-02', 'Trump OR Clinton since:2015-11-02 until:2016-07-10', 'Trump OR Clinton since:2016-07-10 until:2017-03-18', 'Trump OR Clinton since:2017-03-18 until:2017-11-24', 'Trump OR Clinton since:2017-11-24 until:2018-08-02', 'Trump OR Clinton since:2018-08-02 until:2019-04-10', 'Trump OR Clinton since:2019-04-10 until:2019-12-17']
# INFO: Querying Trump OR Clinton since:2006-11-26 until:2007-08-04
# INFO: Querying Trump OR Clinton since:2006-03-21 until:2006-11-26
# INFO: Querying Trump OR Clinton since:2007-08-04 until:2008-04-11
# INFO: Querying Trump OR Clinton since:2008-04-11 until:2008-12-18
# INFO: Querying Trump OR Clinton since:2008-12-18 until:2009-08-26
# INFO: Querying Trump OR Clinton since:2009-08-26 until:2010-05-04
# INFO: Querying Trump OR Clinton since:2011-01-10 until:2011-09-18
# INFO: Querying Trump OR Clinton since:2010-05-04 until:2011-01-10
# INFO: Querying Trump OR Clinton since:2011-09-18 until:2012-05-26
# INFO: Querying Trump OR Clinton since:2012-05-26 until:2013-02-01
# INFO: Querying Trump OR Clinton since:2013-02-01 until:2013-10-10
# INFO: Querying Trump OR Clinton since:2013-10-10 until:2014-06-18
# INFO: Querying Trump OR Clinton since:2015-02-24 until:2015-11-02
# INFO: Querying Trump OR Clinton since:2014-06-18 until:2015-02-24
# INFO: Querying Trump OR Clinton since:2015-11-02 until:2016-07-10
# INFO: Querying Trump OR Clinton since:2016-07-10 until:2017-03-18
# INFO: Querying Trump OR Clinton since:2017-03-18 until:2017-11-24
# INFO: Querying Trump OR Clinton since:2017-11-24 until:2018-08-02
# INFO: Querying Trump OR Clinton since:2018-08-02 until:2019-04-10
# INFO: Querying Trump OR Clinton since:2019-04-10 until:2019-12-17
# INFO: Got 4 tweets for Trump%20OR%20Clinton%20since%3A2006-03-21%20until%3A2006-11-26.
# <twitterscraper.tweet.Tweet object at 0x1204badd8>
# <twitterscraper.tweet.Tweet object at 0x1204bafd0>
# <twitterscraper.tweet.Tweet object at 0x1204a10f0>
# <twitterscraper.tweet.Tweet object at 0x1204a11d0>
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2008-04-11%20until%3A2008-12-18.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2007-08-04%20until%3A2008-04-11.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2011-01-10%20until%3A2011-09-18.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2006-11-26%20until%3A2007-08-04.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2010-05-04%20until%3A2011-01-10.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2008-12-18%20until%3A2009-08-26.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2014-06-18%20until%3A2015-02-24.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2009-08-26%20until%3A2010-05-04.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2012-05-26%20until%3A2013-02-01.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2013-02-01%20until%3A2013-10-10.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2013-10-10%20until%3A2014-06-18.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2019-04-10%20until%3A2019-12-17.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2017-11-24%20until%3A2018-08-02.
# <twitterscraper.tweet.Tweet object at 0x1204bac88>
# <twitterscraper.tweet.Tweet object at 0x1204bab38>
# <twitterscraper.tweet.Tweet object at 0x1204a1278>
# <twitterscraper.tweet.Tweet object at 0x1204a12b0>
# <twitterscraper.tweet.Tweet object at 0x1204a12e8>
# <twitterscraper.tweet.Tweet object at 0x1204a1320>
# <twitterscraper.tweet.Tweet object at 0x1204a1358>
# <twitterscraper.tweet.Tweet object at 0x1204a1390>
# <twitterscraper.tweet.Tweet object at 0x1204a1438>
# <twitterscraper.tweet.Tweet object at 0x1204a1470>
# <twitterscraper.tweet.Tweet object at 0x1204a14a8>
# <twitterscraper.tweet.Tweet object at 0x1204a14e0>
# <twitterscraper.tweet.Tweet object at 0x1204a15c0>
# <twitterscraper.tweet.Tweet object at 0x1204a1668>
# <twitterscraper.tweet.Tweet object at 0x1204a16d8>
# <twitterscraper.tweet.Tweet object at 0x1204a1748>
# <twitterscraper.tweet.Tweet object at 0x1204a1828>
# <twitterscraper.tweet.Tweet object at 0x1204a1898>
# <twitterscraper.tweet.Tweet object at 0x1204a1908>
# <twitterscraper.tweet.Tweet object at 0x1204a1978>
# <twitterscraper.tweet.Tweet object at 0x1204bae80>
# <twitterscraper.tweet.Tweet object at 0x1204baf98>
# <twitterscraper.tweet.Tweet object at 0x1204a11d0>
# <twitterscraper.tweet.Tweet object at 0x1204a1208>
# <twitterscraper.tweet.Tweet object at 0x1204a1080>
# <twitterscraper.tweet.Tweet object at 0x1204a10f0>
# <twitterscraper.tweet.Tweet object at 0x1204a1198>
# <twitterscraper.tweet.Tweet object at 0x1204a1128>
# <twitterscraper.tweet.Tweet object at 0x1204a1a20>
# <twitterscraper.tweet.Tweet object at 0x1204a1a90>
# <twitterscraper.tweet.Tweet object at 0x1204a1b00>
# <twitterscraper.tweet.Tweet object at 0x1204a1b38>
# <twitterscraper.tweet.Tweet object at 0x1204a1ba8>
# <twitterscraper.tweet.Tweet object at 0x1204a1be0>
# <twitterscraper.tweet.Tweet object at 0x1204a1c50>
# <twitterscraper.tweet.Tweet object at 0x1204a1cc0>
# <twitterscraper.tweet.Tweet object at 0x1204a1d68>
# <twitterscraper.tweet.Tweet object at 0x1204a1dd8>
# <twitterscraper.tweet.Tweet object at 0x1204a1e48>
# <twitterscraper.tweet.Tweet object at 0x1204a1e80>
# <twitterscraper.tweet.Tweet object at 0x1204baeb8>
# <twitterscraper.tweet.Tweet object at 0x1204badd8>
# <twitterscraper.tweet.Tweet object at 0x1204a1978>
# <twitterscraper.tweet.Tweet object at 0x1204a1278>
# <twitterscraper.tweet.Tweet object at 0x1204a12b0>
# <twitterscraper.tweet.Tweet object at 0x1204a12e8>
# <twitterscraper.tweet.Tweet object at 0x1204a1358>
# <twitterscraper.tweet.Tweet object at 0x1204a1400>
# <twitterscraper.tweet.Tweet object at 0x1204a13c8>
# <twitterscraper.tweet.Tweet object at 0x1204a1438>
# <twitterscraper.tweet.Tweet object at 0x1204a14a8>
# <twitterscraper.tweet.Tweet object at 0x1204a14e0>
# <twitterscraper.tweet.Tweet object at 0x1204a1518>
# <twitterscraper.tweet.Tweet object at 0x1204a15c0>
# <twitterscraper.tweet.Tweet object at 0x1204a15f8>
# <twitterscraper.tweet.Tweet object at 0x1204a1668>
# <twitterscraper.tweet.Tweet object at 0x1204a1748>
# <twitterscraper.tweet.Tweet object at 0x1204a1780>
# <twitterscraper.tweet.Tweet object at 0x1204a1828>
# <twitterscraper.tweet.Tweet object at 0x1204a1898>
# <twitterscraper.tweet.Tweet object at 0x1204bab70>
# <twitterscraper.tweet.Tweet object at 0x1204baf28>
# <twitterscraper.tweet.Tweet object at 0x1204bac88>
# <twitterscraper.tweet.Tweet object at 0x1204a1240>
# <twitterscraper.tweet.Tweet object at 0x1204a1080>
# <twitterscraper.tweet.Tweet object at 0x1204a1160>
# <twitterscraper.tweet.Tweet object at 0x1204a1a20>
# <twitterscraper.tweet.Tweet object at 0x1204a1a90>
# <twitterscraper.tweet.Tweet object at 0x1204a1b00>
# <twitterscraper.tweet.Tweet object at 0x1204a1ba8>
# <twitterscraper.tweet.Tweet object at 0x1204a1c50>
# <twitterscraper.tweet.Tweet object at 0x1204a1d30>
# <twitterscraper.tweet.Tweet object at 0x1204a1d68>
# <twitterscraper.tweet.Tweet object at 0x1204a1e10>
# <twitterscraper.tweet.Tweet object at 0x1204a1f28>
# <twitterscraper.tweet.Tweet object at 0x1204a9048>
# <twitterscraper.tweet.Tweet object at 0x1204a9128>
# <twitterscraper.tweet.Tweet object at 0x1204a9198>
# <twitterscraper.tweet.Tweet object at 0x1204a9278>
# <twitterscraper.tweet.Tweet object at 0x1204a92e8>
# <twitterscraper.tweet.Tweet object at 0x1204a12b0>
# <twitterscraper.tweet.Tweet object at 0x1204a13c8>
# <twitterscraper.tweet.Tweet object at 0x1204a1438>
# <twitterscraper.tweet.Tweet object at 0x1204a1470>
# <twitterscraper.tweet.Tweet object at 0x1204a14a8>
# <twitterscraper.tweet.Tweet object at 0x1204a14e0>
# <twitterscraper.tweet.Tweet object at 0x1204a1550>
# <twitterscraper.tweet.Tweet object at 0x1204a1518>
# <twitterscraper.tweet.Tweet object at 0x1204a15c0>
# <twitterscraper.tweet.Tweet object at 0x1204a15f8>
# <twitterscraper.tweet.Tweet object at 0x1204a1668>
# <twitterscraper.tweet.Tweet object at 0x1204a16d8>
# <twitterscraper.tweet.Tweet object at 0x1204a1748>
# <twitterscraper.tweet.Tweet object at 0x1204a17b8>
# <twitterscraper.tweet.Tweet object at 0x1204a1780>
# <twitterscraper.tweet.Tweet object at 0x1204a1828>
# <twitterscraper.tweet.Tweet object at 0x1204bae80>
# <twitterscraper.tweet.Tweet object at 0x1204baeb8>
# <twitterscraper.tweet.Tweet object at 0x1204bab38>
# <twitterscraper.tweet.Tweet object at 0x1204baef0>
# <twitterscraper.tweet.Tweet object at 0x1204a1e80>
# <twitterscraper.tweet.Tweet object at 0x1204a10f0>
# <twitterscraper.tweet.Tweet object at 0x1204a1048>
# <twitterscraper.tweet.Tweet object at 0x1204a1160>
# <twitterscraper.tweet.Tweet object at 0x1204a1128>
# <twitterscraper.tweet.Tweet object at 0x1204a1a20>
# <twitterscraper.tweet.Tweet object at 0x1204a1a58>
# <twitterscraper.tweet.Tweet object at 0x1204a1a90>
# <twitterscraper.tweet.Tweet object at 0x1204a1ac8>
# <twitterscraper.tweet.Tweet object at 0x1204a1b00>
# <twitterscraper.tweet.Tweet object at 0x1204a1b70>
# <twitterscraper.tweet.Tweet object at 0x1204a1b38>
# <twitterscraper.tweet.Tweet object at 0x1204a1ba8>
# <twitterscraper.tweet.Tweet object at 0x1204a1c18>
# <twitterscraper.tweet.Tweet object at 0x1204a1be0>
# <twitterscraper.tweet.Tweet object at 0x1204a1c50>
# <twitterscraper.tweet.Tweet object at 0x1204a1cc0>
# <twitterscraper.tweet.Tweet object at 0x1204a1c88>
# <twitterscraper.tweet.Tweet object at 0x1204a1d30>
# <twitterscraper.tweet.Tweet object at 0x1204a1cf8>
# <twitterscraper.tweet.Tweet object at 0x1204a1438>
# <twitterscraper.tweet.Tweet object at 0x1204a15c0>
# <twitterscraper.tweet.Tweet object at 0x1204a15f8>
# <twitterscraper.tweet.Tweet object at 0x1204a1668>
# <twitterscraper.tweet.Tweet object at 0x1204a16d8>
# <twitterscraper.tweet.Tweet object at 0x1204a17b8>
# <twitterscraper.tweet.Tweet object at 0x1204a1780>
# <twitterscraper.tweet.Tweet object at 0x1204a1828>
# <twitterscraper.tweet.Tweet object at 0x1204a1278>
# <twitterscraper.tweet.Tweet object at 0x1204a1080>
# <twitterscraper.tweet.Tweet object at 0x1204a1208>
# <twitterscraper.tweet.Tweet object at 0x1204a10b8>
# <twitterscraper.tweet.Tweet object at 0x1204a1240>
# <twitterscraper.tweet.Tweet object at 0x1204a1d68>
# <twitterscraper.tweet.Tweet object at 0x1204a1dd8>
# <twitterscraper.tweet.Tweet object at 0x1204a1e10>
# <twitterscraper.tweet.Tweet object at 0x1204a1908>
# <twitterscraper.tweet.Tweet object at 0x1204a1e48>
# <twitterscraper.tweet.Tweet object at 0x1204a1f28>
# <twitterscraper.tweet.Tweet object at 0x1204a1fd0>
# <twitterscraper.tweet.Tweet object at 0x1204a10f0>
# <twitterscraper.tweet.Tweet object at 0x1204a1a58>
# <twitterscraper.tweet.Tweet object at 0x1204a1a90>
# <twitterscraper.tweet.Tweet object at 0x1204a1ac8>
# <twitterscraper.tweet.Tweet object at 0x1204a1b70>
# <twitterscraper.tweet.Tweet object at 0x1204a1b38>
# <twitterscraper.tweet.Tweet object at 0x1204a1ba8>
# <twitterscraper.tweet.Tweet object at 0x1204a1c18>
# <twitterscraper.tweet.Tweet object at 0x1204a1be0>
# <twitterscraper.tweet.Tweet object at 0x1204a1c50>
# <twitterscraper.tweet.Tweet object at 0x1204a1cc0>
# <twitterscraper.tweet.Tweet object at 0x1204a12b0>
# <twitterscraper.tweet.Tweet object at 0x1204a1550>
# <twitterscraper.tweet.Tweet object at 0x1204a14e0>
# <twitterscraper.tweet.Tweet object at 0x1204a14a8>
# <twitterscraper.tweet.Tweet object at 0x1204a1470>
# <twitterscraper.tweet.Tweet object at 0x1204a13c8>
# <twitterscraper.tweet.Tweet object at 0x1204a1f98>
# <twitterscraper.tweet.Tweet object at 0x1204a1f60>
# <twitterscraper.tweet.Tweet object at 0x1204a1898>
# <twitterscraper.tweet.Tweet object at 0x1204a15c0>
# <twitterscraper.tweet.Tweet object at 0x1204a1780>
# <twitterscraper.tweet.Tweet object at 0x1204a1278>
# <twitterscraper.tweet.Tweet object at 0x1204a1080>
# <twitterscraper.tweet.Tweet object at 0x1204a1208>
# <twitterscraper.tweet.Tweet object at 0x1204a10b8>
# <twitterscraper.tweet.Tweet object at 0x1204a11d0>
# <twitterscraper.tweet.Tweet object at 0x1204a1d68>
# <twitterscraper.tweet.Tweet object at 0x1204a1dd8>
# <twitterscraper.tweet.Tweet object at 0x1204a1da0>
# <twitterscraper.tweet.Tweet object at 0x1204a1e10>
# <twitterscraper.tweet.Tweet object at 0x1204a1908>
# <twitterscraper.tweet.Tweet object at 0x1204a1e48>
# <twitterscraper.tweet.Tweet object at 0x1204a1f28>
# <twitterscraper.tweet.Tweet object at 0x1204a1eb8>
# <twitterscraper.tweet.Tweet object at 0x1204a1a20>
# <twitterscraper.tweet.Tweet object at 0x1204a19e8>
# <twitterscraper.tweet.Tweet object at 0x1204a1160>
# <twitterscraper.tweet.Tweet object at 0x1204a1048>
# <twitterscraper.tweet.Tweet object at 0x1204a1e80>
# <twitterscraper.tweet.Tweet object at 0x1204a1ac8>
# <twitterscraper.tweet.Tweet object at 0x1204a1be0>
# <twitterscraper.tweet.Tweet object at 0x1204a1c50>
# <twitterscraper.tweet.Tweet object at 0x1204a1cc0>
# <twitterscraper.tweet.Tweet object at 0x1204a1d30>
# <twitterscraper.tweet.Tweet object at 0x1204a1c88>
# <twitterscraper.tweet.Tweet object at 0x1204a12b0>
# <twitterscraper.tweet.Tweet object at 0x1204a1518>
# <twitterscraper.tweet.Tweet object at 0x1204a1550>
# <twitterscraper.tweet.Tweet object at 0x1204a14e0>
# <twitterscraper.tweet.Tweet object at 0x1204a1470>
# <twitterscraper.tweet.Tweet object at 0x1204a13c8>
# <twitterscraper.tweet.Tweet object at 0x1204a1f98>
# <twitterscraper.tweet.Tweet object at 0x1204a1f60>
# <twitterscraper.tweet.Tweet object at 0x1204a16d8>
# <twitterscraper.tweet.Tweet object at 0x1204a1438>
# <twitterscraper.tweet.Tweet object at 0x1204a1358>
# <twitterscraper.tweet.Tweet object at 0x1204baef0>
# <twitterscraper.tweet.Tweet object at 0x1204baeb8>
# <twitterscraper.tweet.Tweet object at 0x1204bab38>
# <twitterscraper.tweet.Tweet object at 0x1204a1828>
# <twitterscraper.tweet.Tweet object at 0x1204a1240>
# <twitterscraper.tweet.Tweet object at 0x1204a11d0>
# <twitterscraper.tweet.Tweet object at 0x1204a1d68>
# <twitterscraper.tweet.Tweet object at 0x1204a1dd8>
# <twitterscraper.tweet.Tweet object at 0x1204a1da0>
# <twitterscraper.tweet.Tweet object at 0x1204a1908>
# <twitterscraper.tweet.Tweet object at 0x1204a1e48>
# <twitterscraper.tweet.Tweet object at 0x1204a1f28>
# <twitterscraper.tweet.Tweet object at 0x1204a1eb8>
# <twitterscraper.tweet.Tweet object at 0x1204a1a20>
# <twitterscraper.tweet.Tweet object at 0x1204a1128>
# <twitterscraper.tweet.Tweet object at 0x1204a19e8>
# <twitterscraper.tweet.Tweet object at 0x1204a1160>
# <twitterscraper.tweet.Tweet object at 0x1204a1048>
# <twitterscraper.tweet.Tweet object at 0x1204a1898>
# <twitterscraper.tweet.Tweet object at 0x1204a1cf8>
# <twitterscraper.tweet.Tweet object at 0x1204a1a90>
# <twitterscraper.tweet.Tweet object at 0x1204a1c18>
# <twitterscraper.tweet.Tweet object at 0x1204a1ba8>
# <twitterscraper.tweet.Tweet object at 0x1204a1ac8>
# <twitterscraper.tweet.Tweet object at 0x1204a1518>
# <twitterscraper.tweet.Tweet object at 0x1204a1550>
# <twitterscraper.tweet.Tweet object at 0x1204a14e0>
# <twitterscraper.tweet.Tweet object at 0x1204a14a8>
# <twitterscraper.tweet.Tweet object at 0x1204a1470>
# <twitterscraper.tweet.Tweet object at 0x1204a1f60>
# <twitterscraper.tweet.Tweet object at 0x1204a17b8>
# <twitterscraper.tweet.Tweet object at 0x1204a1fd0>
# <twitterscraper.tweet.Tweet object at 0x1204a16d8>
# <twitterscraper.tweet.Tweet object at 0x1204a1668>
# <twitterscraper.tweet.Tweet object at 0x1204a1438>
# <twitterscraper.tweet.Tweet object at 0x1204a1358>
# <twitterscraper.tweet.Tweet object at 0x1204a12e8>
# <twitterscraper.tweet.Tweet object at 0x1204a1320>
# <twitterscraper.tweet.Tweet object at 0x1204a10b8>
# <twitterscraper.tweet.Tweet object at 0x1204a1208>
# <twitterscraper.tweet.Tweet object at 0x1204a1198>
# <twitterscraper.tweet.Tweet object at 0x1204a1278>
# <twitterscraper.tweet.Tweet object at 0x1204a1a58>
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2015-11-02%20until%3A2016-07-10.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2016-07-10%20until%3A2017-03-18.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2011-09-18%20until%3A2012-05-26.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2017-03-18%20until%3A2017-11-24.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2018-08-02%20until%3A2019-04-10.
# INFO: Got 20 tweets for Trump%20OR%20Clinton%20since%3A2015-02-24%20until%3A2015-11-02.
# <twitterscraper.tweet.Tweet object at 0x1204a1b70>
# <twitterscraper.tweet.Tweet object at 0x1204a1da0>
# <twitterscraper.tweet.Tweet object at 0x1204a1908>
# <twitterscraper.tweet.Tweet object at 0x1204a1e48>
# <twitterscraper.tweet.Tweet object at 0x1204a1eb8>
# <twitterscraper.tweet.Tweet object at 0x1204a1128>
# <twitterscraper.tweet.Tweet object at 0x1204a19e8>
# <twitterscraper.tweet.Tweet object at 0x1204a1160>
# <twitterscraper.tweet.Tweet object at 0x1204a1048>
# <twitterscraper.tweet.Tweet object at 0x1204a1898>
# <twitterscraper.tweet.Tweet object at 0x1204a1a90>
# <twitterscraper.tweet.Tweet object at 0x1204a1c18>
# <twitterscraper.tweet.Tweet object at 0x1204a15c0>
# <twitterscraper.tweet.Tweet object at 0x1204a12b0>
# <twitterscraper.tweet.Tweet object at 0x1204a1c88>
# <twitterscraper.tweet.Tweet object at 0x1204a1d30>
# <twitterscraper.tweet.Tweet object at 0x1204a1cc0>
# <twitterscraper.tweet.Tweet object at 0x1204a1c50>
# <twitterscraper.tweet.Tweet object at 0x1204a10f0>
# <twitterscraper.tweet.Tweet object at 0x1204baef0>
# <twitterscraper.tweet.Tweet object at 0x1204a1be0>
# <twitterscraper.tweet.Tweet object at 0x1204a1f98>
# <twitterscraper.tweet.Tweet object at 0x1204a13c8>
# <twitterscraper.tweet.Tweet object at 0x1204a17b8>
# <twitterscraper.tweet.Tweet object at 0x1204a1fd0>
# <twitterscraper.tweet.Tweet object at 0x1204a16d8>
# <twitterscraper.tweet.Tweet object at 0x1204a1668>
# <twitterscraper.tweet.Tweet object at 0x1204a1438>
# <twitterscraper.tweet.Tweet object at 0x1204a1358>
# <twitterscraper.tweet.Tweet object at 0x1204a1320>
# <twitterscraper.tweet.Tweet object at 0x1204a10b8>
# <twitterscraper.tweet.Tweet object at 0x1204a1208>
# <twitterscraper.tweet.Tweet object at 0x1204a1080>
# <twitterscraper.tweet.Tweet object at 0x1204a1198>
# <twitterscraper.tweet.Tweet object at 0x1204a1278>
# <twitterscraper.tweet.Tweet object at 0x1204a1b00>
# <twitterscraper.tweet.Tweet object at 0x1204a1e80>
# <twitterscraper.tweet.Tweet object at 0x1204a1dd8>
# <twitterscraper.tweet.Tweet object at 0x1204a1d68>
# <twitterscraper.tweet.Tweet object at 0x1204a11d0>
# <twitterscraper.tweet.Tweet object at 0x1204a1e10>
# <twitterscraper.tweet.Tweet object at 0x1204a1128>
# <twitterscraper.tweet.Tweet object at 0x1204a19e8>
# <twitterscraper.tweet.Tweet object at 0x1204a1160>
# <twitterscraper.tweet.Tweet object at 0x1204a1048>
# <twitterscraper.tweet.Tweet object at 0x1204a1898>
# <twitterscraper.tweet.Tweet object at 0x1204a1cf8>
# <twitterscraper.tweet.Tweet object at 0x1204a1a90>
# <twitterscraper.tweet.Tweet object at 0x1204a1c18>
# <twitterscraper.tweet.Tweet object at 0x1204a15c0>
# <twitterscraper.tweet.Tweet object at 0x1204a12b0>
# <twitterscraper.tweet.Tweet object at 0x1204a1c88>
# <twitterscraper.tweet.Tweet object at 0x1204a1d30>
# <twitterscraper.tweet.Tweet object at 0x1204a1cc0>
# <twitterscraper.tweet.Tweet object at 0x1204a10f0>
# <twitterscraper.tweet.Tweet object at 0x1204a1ba8>
# <twitterscraper.tweet.Tweet object at 0x1204a14a8>
# <twitterscraper.tweet.Tweet object at 0x1204a1518>
# <twitterscraper.tweet.Tweet object at 0x1204a1b38>
# <twitterscraper.tweet.Tweet object at 0x1204a1828>
# <twitterscraper.tweet.Tweet object at 0x1204a1f98>
# <twitterscraper.tweet.Tweet object at 0x1204a1668>
# <twitterscraper.tweet.Tweet object at 0x1204a1438>
# <twitterscraper.tweet.Tweet object at 0x1204a1358>
# <twitterscraper.tweet.Tweet object at 0x1204a12e8>
# <twitterscraper.tweet.Tweet object at 0x1204a1320>
# <twitterscraper.tweet.Tweet object at 0x1204a1780>
# <twitterscraper.tweet.Tweet object at 0x1204a10b8>
# <twitterscraper.tweet.Tweet object at 0x1204a1208>
# <twitterscraper.tweet.Tweet object at 0x1204a1080>
# <twitterscraper.tweet.Tweet object at 0x1204a1198>
# <twitterscraper.tweet.Tweet object at 0x1204a1278>
# <twitterscraper.tweet.Tweet object at 0x1204a1400>
# <twitterscraper.tweet.Tweet object at 0x1204a1dd8>
# <twitterscraper.tweet.Tweet object at 0x1204a1d68>
# <twitterscraper.tweet.Tweet object at 0x1204a1da0>
# <twitterscraper.tweet.Tweet object at 0x1204a1a20>
# <twitterscraper.tweet.Tweet object at 0x1204a1eb8>
# <twitterscraper.tweet.Tweet object at 0x1204a1f28>
# <twitterscraper.tweet.Tweet object at 0x1204a1e48>
# <twitterscraper.tweet.Tweet object at 0x1204a1e10>
# <twitterscraper.tweet.Tweet object at 0x1204a1c18>
# <twitterscraper.tweet.Tweet object at 0x1204a15c0>
# <twitterscraper.tweet.Tweet object at 0x1204a12b0>
# <twitterscraper.tweet.Tweet object at 0x1204a1c88>
# <twitterscraper.tweet.Tweet object at 0x1204a1d30>
# <twitterscraper.tweet.Tweet object at 0x1204a1c50>
# <twitterscraper.tweet.Tweet object at 0x1204a10f0>
# <twitterscraper.tweet.Tweet object at 0x1204a1ba8>
# <twitterscraper.tweet.Tweet object at 0x1204a1470>
# <twitterscraper.tweet.Tweet object at 0x1204a14a8>
# <twitterscraper.tweet.Tweet object at 0x1204a1550>
# <twitterscraper.tweet.Tweet object at 0x1204a1518>
# <twitterscraper.tweet.Tweet object at 0x1204a1240>
# <twitterscraper.tweet.Tweet object at 0x1204a1b38>
# <twitterscraper.tweet.Tweet object at 0x1204a11d0>
# <twitterscraper.tweet.Tweet object at 0x1204a16d8>
# <twitterscraper.tweet.Tweet object at 0x1204a1fd0>
# <twitterscraper.tweet.Tweet object at 0x1204a17b8>
# <twitterscraper.tweet.Tweet object at 0x1204a1f60>
# <twitterscraper.tweet.Tweet object at 0x1204a1908>
# <twitterscraper.tweet.Tweet object at 0x1204a1780>
# <twitterscraper.tweet.Tweet object at 0x1204a10b8>
# <twitterscraper.tweet.Tweet object at 0x1204a1208>
# <twitterscraper.tweet.Tweet object at 0x1204a1080>
# <twitterscraper.tweet.Tweet object at 0x1204a1198>
# <twitterscraper.tweet.Tweet object at 0x1204a1278>
# <twitterscraper.tweet.Tweet object at 0x1204a1b00>
# <twitterscraper.tweet.Tweet object at 0x1204a1400>
# <twitterscraper.tweet.Tweet object at 0x1204a1dd8>
# <twitterscraper.tweet.Tweet object at 0x1204a1d68>
# <twitterscraper.tweet.Tweet object at 0x1204a1da0>
# <twitterscraper.tweet.Tweet object at 0x1204a1eb8>
# <twitterscraper.tweet.Tweet object at 0x1204a1828>
# <twitterscraper.tweet.Tweet object at 0x1204a1a90>
# <twitterscraper.tweet.Tweet object at 0x1204a1898>
# <twitterscraper.tweet.Tweet object at 0x1204a1048>
# <twitterscraper.tweet.Tweet object at 0x1204a1160>
# <twitterscraper.tweet.Tweet object at 0x1204a13c8>
# <twitterscraper.tweet.Tweet object at 0x1204a1a58>
# <twitterscraper.tweet.Tweet object at 0x1204a19e8>
# <twitterscraper.tweet.Tweet object at 0x1204a1cc0>
# <twitterscraper.tweet.Tweet object at 0x1204a1c50>
# <twitterscraper.tweet.Tweet object at 0x1204a10f0>
# <twitterscraper.tweet.Tweet object at 0x1204a1ba8>
# <twitterscraper.tweet.Tweet object at 0x1204a1470>
# <twitterscraper.tweet.Tweet object at 0x1204a1550>
# <twitterscraper.tweet.Tweet object at 0x1204a14e0>
# <twitterscraper.tweet.Tweet object at 0x1204a1518>
# <twitterscraper.tweet.Tweet object at 0x1204a1240>
# <twitterscraper.tweet.Tweet object at 0x1204a1ac8>
# <twitterscraper.tweet.Tweet object at 0x1204a11d0>
# <twitterscraper.tweet.Tweet object at 0x1204a16d8>
# <twitterscraper.tweet.Tweet object at 0x1204a1fd0>
# <twitterscraper.tweet.Tweet object at 0x1204a17b8>
# <twitterscraper.tweet.Tweet object at 0x1204a1e48>
# <twitterscraper.tweet.Tweet object at 0x1204a1358>
# <twitterscraper.tweet.Tweet object at 0x1204a1f98>
# <twitterscraper.tweet.Tweet object at 0x1204a1b70>
# <twitterscraper.tweet.Tweet object at 0x1204baef0>
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
# could not ensure all messages were consumed prior to exiting
