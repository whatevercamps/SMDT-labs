# %%
import numpy as np

# %% [markdown]
# ### lab section (don't run)

# %%
values = [4,4,4,4,4]

# %%
np_mean = np.mean(values)
np_var = np.var(values)
total = np.sum(values)

# %%
print(np_mean, np_var, len(values))
# Out:
# 4.0 0.0 5

# %%
new_value = 100
new_mean = np_mean + (new_value - np_mean)/(len(values) + 1)
n = len(values) + 1
#new_std = (((len(values) - 1) * np_var) + ((new_value - new_mean)*(new_value - np_mean)))/len(values)
new_sdt = ((n - 2) * np_var + (new_value - new_mean)*(new_value - np_mean))/(n-1)
#new_std = ((n - 2) * np_var + (n - 1)*((np_mean - new_mean)**2) + ((new_value - new_mean)**2))/(n - 1)

# %%
new_mean
# Out:
# 20.0

# %%
np.sqrt(new_std)
# Out:
# 39.191835884530846

# %%
np.std(values + [100], ddof=1)
# Out:
# 39.191835884530846

# %%
np.mean(values + [100])
# Out:
# 20.0

# %% [markdown]
# ### end of lab section

# %% [markdown]
# ## Calculating std for each tweet

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://54.90.49.105:27017", username='rw_admin_smdt', password='HolocaustoDel84', authSource="smdt")
db = client["smdt"]
tweets_collection = db['tweets']

# %%
tweets = [tweet for tweet in tweets_collection.find({})]

# %%
import pandas as pd
df = pd.DataFrame(tweets)

# %%
df.to_csv("bd-tw-24072020.csv", index=False)

# %%
import json
json.dump(tweets, open("bd-tw-24072020.json", "w"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-fcfe2076ded8> in <module>
#       1 import json
# ----> 2 json.dump(tweets, open("bd-tw-24072020.json", "w"))
#
# ~/opt/anaconda3/lib/python3.7/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~/opt/anaconda3/lib/python3.7/json/encoder.py in _iterencode(o, _current_indent_level)
#     427             yield _floatstr(o)
#     428         elif isinstance(o, (list, tuple)):
# --> 429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# ...

# %%
tweets_std = np.std(tweets_sim, ddof=1)

# %%
tweets_mean = np.mean(tweets_sim)

# %%
stats_colleccion = db['col_stats']

# %%
stats_colleccion.insert_one({"mean":  tweets_mean, "std": tweets_std})

# %%
pd.set_option('max_colwidth', 4000)
pd.set_option('max_columns', 4000)
pd.set_option('max_rows', 4000)
df.head()
# Out:
#                         _id  has_media hashtags img_urls  is_replied  \
# 0  5ef4db99ae0112ddab8f5c9d      False       []       []       False
# 1  5ef4db99ae0112ddab8f5c9e      False       []       []       False
# 2  5ef4db99ae0112ddab8f5c9f      False       []       []       False
# 3  5ef4db99ae0112ddab8f5ca0      False       []       []       False
# 4  5ef4db99ae0112ddab8f5ca1      False       []       []       False
#
#    is_reply_to  likes links parent_tweet_id  replies  \
# 0        False      0    []                        0
# 1        False      0    []                        0
# 2        False      0    []                        0
# 3        False      0    []                        0
# 4         True      0    []      4148965908        0
#
#                                         reply_to_users  retweets  \
# 0                                                   []         0
# 1                                                   []         0
# ...

# %%
dff = pd.DataFrame([d for d in tweets if "copa" in d["text"] and "diu" in d["text"]])

# %%
dff
# Out:
#                         _id  has_media hashtags img_urls  is_replied  \
# 0  5ef5085c054b870f007cab0e      False       []       []        True
# 1  5ef51b9b054b870f007e0418      False       []       []        True
# 2  5ef62aa92ef50f2bb344780a      False       []       []       False
# 3  5f075cbfbb75f4e5695a73f2      False       []       []       False
#
#    is_reply_to  likes links      parent_tweet_id  replies  \
# 0         True      3    []  1171427558384005120        2
# 1         True      4    []  1265667455315333121        1
# 2        False      0    []                             0
# 3         True      0    []   860174205274509312        0
#
#                                                                                                   reply_to_users  \
# 0                                          [{'screen_name': 'caroconinsomnio', 'user_id': '733128881616609280'}]
# ...

# %%
len(dff)
# Out:
# 4

# %%
dfff = pd.DataFrame([d for d in tweets if ("abortivo" in d["text"] and "anticonceptivo" in d["text"]) or ("abortivo" in d["text"] and "diu" in d["text"])])

# %%
dfff
# Out:
#                           _id  has_media  \
# 0    5ef4fa0f054b870f007c2bbb      False
# 1    5ef50479054b870f007c3ed4      False
# 2    5ef504fc054b870f007c4c44      False
# 3    5ef504fd054b870f007c4c5e      False
# 4    5ef5178a054b870f007d80bf      False
# 5    5ef51793054b870f007d81fa      False
# 6    5ef51797054b870f007d829c      False
# 7    5ef51798054b870f007d82bd      False
# 8    5ef51798054b870f007d82be      False
# 9    5ef51798054b870f007d82bf      False
# 10   5ef51798054b870f007d82c0      False
# 11   5ef51798054b870f007d82c1      False
# 12   5ef51798054b870f007d82c2      False
# 13   5ef51798054b870f007d82c5      False
# 14   5ef51798054b870f007d82c7      False
# 15   5ef51798054b870f007d82c8      False
# 16   5ef51798054b870f007d82c9      False
# 17   5ef51798054b870f007d82ca      False
# 18   5ef51798054b870f007d82cd      False
# 19   5ef517a1054b870f007d843f      False
# 20   5ef517aa054b870f007d8570      False
# 21   5ef517ac054b870f007d85b8       True
# ...

# %%
len(dfff)
# Out:
# 316
