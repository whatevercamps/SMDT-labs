# %%
# import basic libraries
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('spanish')
import json
import unidecode
import spacy
nlp = spacy.load("es_core_news_md")

# %%
# Getting "anti-taxonomy"
anti_taxonomy_file_name = "anti_taxonomy_export_2.json"
anti_taxonomy_file = open(anti_taxonomy_file_name, 'r')
anti_taxonomy = json.load(anti_taxonomy_file) 
anti_taxonomy += ['stroke', 'span', 'trebuchet', 'webkit', 'kerning', 'calibri', 'font', 'text', 'margin', 'm' , 'ten', 'www', 'https' 'https', 'none']

# %%
from fuzzywuzzy import process

def is_in_anti_tax(sr):
    highest = process.extractOne(sr,anti_taxonomy)
    return highest[1] < 95
# Out:
# /Users/davidbautista/opt/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# function to clean text
def review_to_words(raw_review):
    # 1. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", raw_review) 

    # 2. Convert to lower case and only words
    only_words = letters_only.lower()
    only_words = " ".join(only_words.split())
    # 2.1 the nlp doc and words ❤️ 
    doc = nlp(only_words)
    lexical_tokens = [tok.lemma_ for tok in doc if tok.pos_ != 'PRON' and not (tok.is_punct | tok.is_stop)]
    words = [t.lower() for t in lexical_tokens if len(t) > 2 and t.isalpha()]
    # 3. Remove Stopwords. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("spanish"))  
    # 4. Remove stop words
    meaningful_words = [w for w in words if not w in stops]  #returns a list 
    # 4.1 if you want remove words in anti-taxonomy
    #meaningful_words = list(filter(is_in_anti_tax, meaningful_words)) 
    meaningful_words = [w for w in meaningful_words if w.strip() not in anti_taxonomy]
    # 5. Stem words. Need to define porter stemmer above
    #meaningful_words = [(lambda x: stemmer.stem(x) if len(x) > 5 else x)(word) for word in meaningful_words]
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %% [markdown]
# # Plural to singular lab (don't run)

# %%
processed_text = nlp("sifilis amores pasados perros casemonos guapos pepinillos")
lemma_tags = {"NNS", "NNPS"}
for token in processed_text:
    lemma = token.text
    if token.tag_ in lemma_tags:
        print(token.lemma_)
        lemma = token.lemma_

# %%
[p.lemma for p in processed_text]
# Out:
# [9993756361066428433,
#  7569031656004518897,
#  8365782747564503572,
#  1889751909063932040,
#  2518710851894020402,
#  388792319402109172,
#  1822172757761197604]

# %% [markdown]
# # lab final (run from next line)

# %%
file = open("sin_tildes_sexperto.json", 'r')
questions = json.load(file)

# %%
questions[0]
# Out:
# {'Name': '?Es necesario tomar anticoncepcion de emergencia cuando se utiliza el anillo anticonceptivo vaginal (NuvaRing) sin condon?',
#  'respuestas_juntas': 'Solo cuando comienzas a usar el anillo anticonceptivo vaginal en un dia diferente a los primeros cinco dias de la menstruacion, es necesario utilizar un metodo anticonceptivo adicional. Si este es tu caso y no usaste condon si seria necesario usar anticoncepcion de emergencia. Te recomiendo asistir a una asesoria en anticoncepcion en tu centro de atencion en salud. Recuerda utilizar condon en todas las relaciones sexuales.'}

# %%
# apply it to our text data   
# dataset is named wine_data and the text are in the column "wmn"  
processed_wmn = [review_to_words("{} {}".format(question["Name"], question["respuestas_juntas"])) for question in questions] 
len(processed_wmn)
# Out:
# 1137

# %%
" ".join(processed_wmn[0].split())
# Out:
# 'tomar anticoncepcion emergencia anillar anticonceptivo vaginal nuvaring condon anillar anticonceptivo vaginal menstruacion anticonceptivo casar condon serio anticoncepcion emergencia recomer asistir asesoria anticoncepcion centrar atencion salud condon relacionar sexual'

# %%
# build a corpus for the word2vec model  
def build_corpus(data):
    corpus = []
    for sentence in data:
        sentence = " ".join(sentence.split())
        word_list = sentence.split(" ")  
        #corpus.append([(lambda x: x[:-2] if x[-2:] == 'es' and len(x) > 3 else (x[:-1] if x[-1:] == "s" and len(x) > 3 else x))(w) for w in word_list])   
        corpus.append(word_list)   
    return corpus

# %%
corpus = build_corpus(processed_wmn)
len(corpus)
# Out:
# 1137

# %%
import pickle
with open('corpus_sexperto_with_lemma_with_s-04062020.pkl', 'wb') as corpus_export_file:
    pickle.dump(corpus, corpus_export_file)

# %% [markdown]
# # Thanks Sexperto ❤️🤓

# %%
# load the word2vec algorithm from the gensim library  
from gensim.models import word2vec  
# run the model  
model = word2vec.Word2Vec(corpus, size=3, window=4, min_count=30, workers=4)
#model = word2vec.Word2Vec(corpus, size=30, window=4, min_count=30, workers=4)
#model = word2vec.Word2Vec(corpus, size=300, window=4, min_count=30, workers=4)
#model = word2vec.Word2Vec(corpus, size=3000, window=5, min_count=30, workers=4)
len(model.wv.vocab)
# Out:
# 317

# %%
# A ver iterando sobre 
def getModelByIteratingMin_count(words):
    modelBIMC = None
    min_count = 3000
    while true:
        modelBIMC = word2vec.Word2Vec(corpus, size=200, window=5, min_count=1000, workers=4)

# %%
min_words = ["embarazo", "pastillas", ]

# %%
[(item[0], round(item[1],5)) for item in model.wv.most_similar('anticonceptivo', topn=50)]
# Out:
# [('dudar', 0.99925),
#  ('garantizar', 0.99924),
#  ('requerir', 0.998),
#  ('alcanzar', 0.99796),
#  ('regular', 0.99764),
#  ('voluntario', 0.99764),
#  ('tomar', 0.99761),
#  ('temer', 0.99756),
#  ('asesorar', 0.99713),
#  ('medicamento', 0.99711),
#  ('metodos', 0.99699),
#  ('emergencia', 0.99697),
#  ('especificar', 0.99666),
#  ('pastilla', 0.99633),
#  ('vasectomia', 0.99613),
#  ('descartar', 0.99597),
#  ('necesidad', 0.99583),
#  ('linear', 0.99528),
#  ('hora', 0.99504),
#  ('humano', 0.99467),
#  ('acceso', 0.99377),
#  ('acudir', 0.99374),
#  ('querer', 0.99371),
#  ('jovenes', 0.99369),
#  ('comunicacion', 0.99342),
#  ('cortar', 0.99322),
#  ('efectividad', 0.99317),
#  ('duracion', 0.99293),
#  ('ser', 0.99277),
#  ('apoyar', 0.99276),
#  ('gratuito', 0.99251),
#  ('recomendar', 0.99223),
#  ('desear', 0.99186),
#  ('estudio', 0.99176),
#  ('fundamental', 0.99132),
#  ('hijo', 0.99114),
#  ('disminuir', 0.99113),
#  ('dejar', 0.99073),
#  ('situacion', 0.99071),
#  ('disfrutar', 0.99054),
#  ('https', 0.99031),
#  ('correcto', 0.99002),
#  ('subdermico', 0.99),
#  ('bogota', 0.98998),
#  ('colombia', 0.98998),
#  ('necesitar', 0.98943),
#  ('colombiano', 0.98786),
#  ('trompa', 0.9876),
#  ('excitacion', 0.98751),
#  ('valorar', 0.98711)]

# %%
[x for x in model.wv.vocab][-25:]
# Out:
# ['atraccion',
#  'infectar',
#  'cortar',
#  'organo',
#  'colombiano',
#  'pubertad',
#  'virgen',
#  'presion',
#  'referir',
#  'olor',
#  'malo',
#  'higiene',
#  'gustar',
#  'delito',
#  'citologia',
#  'voluntario',
#  'papiloma',
#  'humanar',
#  'vph',
#  'legal',
#  'pornografia',
#  'vacuno',
#  'victimar',
#  'experiencia',
#  'denunciar']

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# define the function to compute the dimensionality reduction
# and then produce the biplot

"Creates a TSNE model and plots it"
labels = []
tokens = []

for word in model.wv.vocab:
    tokens.append(model[word])
    labels.append(word)

tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500)
new_values = tsne_model.fit_transform(tokens)

x = []
y = []
for value in new_values:
    x.append(value[0])
    y.append(value[1])

plt.figure(figsize=(32, 32)) 
for i in range(len(x)):
    plt.scatter(x[i],y[i])
    plt.annotate(labels[i],
                 xy=(x[i], y[i]),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')
plt.savefig('foo_comp_4.png')
plt.savefig('foo_comp_4.pdf')

# %% [markdown]
# # Taxonomy build GENSIM

# %%
from gensim.parsing.preprocessing import remove_stopwords
from gensim.summarization import keywords
import warnings
warnings.filterwarnings("ignore")

# %%
textt = " ".join([" ".join(c) for c in corpus])

# %%
values = keywords(text=textt,split=True,scores=True, lemmatize=True)
len(values)
# Out:
# 730

# %%
pd.options.display.max_rows = 999
data_keywords = pd.DataFrame(values,columns=['keyword','score'])
data_keywords = data_keywords.sort_values('score',ascending=False)
data_keywords.head(100)
# Out:
#                                               keyword     score
# 0                                            personar  0.265331
# 1                                               poder  0.188799
# 2                                           saludable  0.167994
# 3   relacionar sexual parejo embarazar eyacular va...  0.141382
# 4                                              condon  0.139714
# 5                                               casar  0.137672
# 6                                                 ano  0.119634
# 7                                              sentir  0.119131
# 8                                              causar  0.104444
# 9                                          sexualidad  0.093179
# 10                              infeccion transmision  0.084826
# 11                                             normal  0.083858
# 12                                               sexo  0.082587
# 13                                               edad  0.077703
# 14                                            sangrar  0.077423
# 15                                          practicar  0.074041
# 16  tomar anticoncepcion emergencia anillar antico...  0.070839
# 17                                          situacion  0.068088
# 18                                   genital femenino  0.066282
# 19                                 probable presentar  0.065514
# 20                                               vida  0.064678
# 21                                           vaginiti  0.064355
# 22                                             desear  0.063393
# 23                                             ayudar  0.062080
# 24                                         enfermedad  0.061734
# 25                                 siguiente relacion  0.061076
# 26                                       menstruacion  0.059844
# 27                           recomer asistir asesoria  0.059059
# 28                                    caso recomendar  0.055305
# 29                                        medicamento  0.055030
# 30                             incomodar tamano penar  0.054571
# 31                                             metodo  0.053735
# 32                                            iniciar  0.051897
# 33                                          tipo vaya  0.051402
# 34                      informacion invitar consultar  0.051056
# 35                                    insertar cuerpo  0.050165
# 36                                           resultar  0.049100
# 37                                          disminuir  0.048263
# 38                                            hormona  0.048069
# 39                                             llamar  0.048007
# 40                                           pastilla  0.046938
# 41                                           requerir  0.046193
# 42                             caracteristica adecuar  0.046136
# 43                                           procesar  0.044953
# 44                                       orientacione  0.044640
# 45                                       masturbacion  0.044242
# 46                                               hijo  0.042172
# 47                                   formular medicar  0.041892
# 48                                            segundo  0.041830
# 49                                         significar  0.041667
# 50                                           victimar  0.041643
# 51                                           ereccion  0.041611
# 52                                          testiculo  0.040982
# 53                                        posibilidad  0.040894
# 54                             oral periodo menstrual  0.040378
# 55                                              utero  0.040327
# 56                                       dolor cabeza  0.040126
# 57                                             placer  0.040093
# 58                                            cirugia  0.040092
# 59                                           lesionar  0.040036
# 60                                        identificar  0.039443
# 61                         eyaculacion cantidad semen  0.039405
# 62                estudio temer encontrar interaccion  0.038495
# 63                               colombia dispositivo  0.038031
# 64                                            afectar  0.037948
# 65                                    efecto negativo  0.037587
# 66                                              algun  0.036712
# 67                                                eps  0.036628
# 68                                             orinar  0.036455
# 69                                 descartar problema  0.036436
# 70                 confiable querer totalmente seguro  0.035426
# 71                                               http  0.035373
# 72                                             probar  0.035267
# 73                          especificar prepucio piel  0.034821
# 74                                             pagina  0.034543
# 75                                            definir  0.034112
# 76                                            asociar  0.034106
# 77                                          violencia  0.033667
# 78                                           condonar  0.033321
# 79                                         comunicate  0.033073
# 80                                               zona  0.032815
# 81                                               acto  0.032014
# 82                                      recibir flujo  0.032006
# 83                                           vih sida  0.031633
# 84                                             factor  0.031533
# 85                                              mesar  0.031485
# 86                                     etcetera haber  0.031467
# 87                                             tratar  0.031283
# 88                                        condicionar  0.031202
# 89                                          disfrutar  0.030877
# 90                               barrera preservativo  0.030874
# 91                                 frecuentar conocer  0.030795
# 92                        hormonal inyectable pildora  0.030702
# 93                                  prevenir embarazo  0.030604
# 94                                          masculino  0.030545
# 95                                 garantizar entidad  0.030363
# 96                                             marcar  0.030268
# 97                                       feto abortar  0.029944
# 98                                         virginidad  0.029586
# 99                                          solicitar  0.029568

# %%
len(data_keywords)
# Out:
# 1022

# %% [markdown]
# # Taxonomy build using Spacy

# %%
from collections import Counter
from functools import reduce

# %%
words_for_tokenization = reduce(lambda x,y :x+y, corpus)
len(words_for_tokenization)
# Out:
# 54300

# %%
word_freq = Counter(words_for_tokenization)
common_words = word_freq.most_common(int(54300/2))

# %%
[c[0] for c in common_words]
# Out:
# ['sexual',
#  'relacion',
#  'infeccion',
#  'person',
#  'embaraz',
#  'salud',
#  'condon',
#  'anticoncept',
#  'poder',
#  'transmision',
#  'asist',
#  'parej',
#  'recom',
#  'anticoncepcion',
#  'consult',
#  'sent',
#  'ano',
#  'casar',
#  'present',
#  'efect',
#  'tomar',
#  'informacion',
#  'pagin',
#  'sexo',
#  'derech',
#  'medic',
#  'penar',
#  'dolor',
#  'cau',
#  'adecu',
#  'citar',
#  'genital',
#  'des',
#  'sangr',
#  'tipo',
#  'recib',
#  'preven',
#  'normal',
#  'quer',
#  'vaginal',
#  'entid',
#  'edad',
#  'practic',
#  'atencion',
#  'hormonal',
#  'recomend',
#  'inici',
#  'metod',
#  'vida',
#  'asesori',
#  'vagin',
#  'pastill',
#  'oral',
#  'menstrual',
#  'menstruacion',
#  'cuerp',
#  'vih',
#  'enfermed',
#  'sexpert',
#  'segund',
#  'problem',
#  'sintom',
#  'fisic',
#  'emergent',
#  'situacion',
#  'orientacion',
#  'eyaculacion',
#  'ayud',
#  'violenci',
#  'encontr',
#  'proteg',
#  'siguient',
#  'caso',
#  'reproduct',
#  'solicit',
#  'nec',
#  'femenin',
#  'penetracion',
#  'prob',
#  'medicament',
#  'hijo',
#  'afect',
#  'contact',
#  'human',
#  'disminu',
#  'centr',
#  'orgasm',
#  'plac',
#  'abort',
#  'period',
#  'colombi',
#  'anal',
#  'eps',
#  'inclu',
#  'conten',
#  'result',
#  'victim',
#  'temer',
#  'condicion',
#  'masturbacion',
#  'dudar',
#  'especific',
#  'implant',
#  'valoracion',
#  'activ',
#  'conoc',
#  'hormon',
#  'disfrut',
#  'cicl',
#  'segur',
#  'algun',
#  'proc',
#  'semen',
#  'requer',
#  'especial',
#  'espermatozoid',
#  'frecuent',
#  'invit',
#  'posibil',
#  'identific',
#  'barrer',
#  'ereccion',
#  'piel',
#  'taman',
#  'acto',
#  'http',
#  'unico',
#  'psicolog',
#  'lin',
#  'alter',
#  'lesion',
#  'abu',
#  'adquir',
#  'plan',
#  'garantiz',
#  'disposit',
#  'diu',
#  'testicul',
#  'orin',
#  'signific',
#  'haber',
#  'preserv',
#  'razon',
#  'milisegund',
#  'llam',
#  'excitacion',
#  'utero',
#  'regul',
#  'pildor',
#  'protegert',
#  'masculin',
#  'asoci',
#  'contagi',
#  'cirugi',
#  'factor',
#  'lubricacion',
#  'valor',
#  'atraccion',
#  'sistem',
#  'respon',
#  'trat',
#  'liquid',
#  'correct',
#  'gust',
#  'ser',
#  'acced',
#  'seno',
#  'ley',
#  'himen',
#  'legal',
#  'transmit',
#  'necesit',
#  'nivel',
#  'its',
#  'organ',
#  'consent',
#  'defin',
#  'eyacul',
#  'adolescent',
#  'asesor',
#  'general',
#  'estimulacion',
#  'zona',
#  'masturb',
#  'social',
#  'ovulo',
#  'molesti',
#  'comun',
#  'comod',
#  'emocional',
#  'subderm',
#  'secundari',
#  'duracion',
#  'presion',
#  'virgin',
#  'funcion',
#  'discapac',
#  'acompan',
#  'mesar',
#  'sida',
#  'acud',
#  'delit',
#  'papilom',
#  'vph',
#  'placenter',
#  'ver',
#  'infect',
#  'cantid',
#  'prevencion',
#  'obten',
#  'benefici',
#  'intrauterin',
#  'exam',
#  'dobl',
#  'control',
#  'marc',
#  'higien',
#  'malo',
#  'uterin',
#  'fertil',
#  'compart',
#  'lubric',
#  'libr',
#  'empez',
#  'manej',
#  'alto',
#  'inmediat',
#  'vacun',
#  'bajo',
#  'atra',
#  'establec',
#  'sifili',
#  'estimul',
#  'product',
#  'gratuit',
#  'sustanci',
#  'denunci',
#  'adicional',
#  'probabil',
#  'incomod',
#  'seman',
#  'apoy',
#  'decision',
#  'mes',
#  'joven',
#  'refer',
#  'coloc',
#  'largo',
#  'inter',
#  'respet',
#  'citologi',
#  'voluntari',
#  'descart',
#  'retra',
#  'consecuent',
#  'referenci',
#  'erot',
#  'ocasion',
#  'secrecion',
#  'famili',
#  'orient',
#  'medicin',
#  'cort',
#  'estudi',
#  'diferenci',
#  'comunicacion',
#  'vasectomi',
#  'comunicart',
#  'interrupcion',
#  'inflamacion',
#  'fundamental',
#  'opcion',
#  'previ',
#  'flujo',
#  'dejar',
#  'realiz',
#  'diver',
#  'inform',
#  'hora',
#  'estr',
#  'apropi',
#  'dificult',
#  'excit',
#  'basar',
#  'experient',
#  'agend',
#  'explor',
#  'esper',
#  'etceter',
#  'tromp',
#  'negat',
#  'exist',
#  'inyect',
#  'experiment',
#  'herp',
#  'olor',
#  'prepuci',
#  'unica',
#  'oportun',
#  'muscul',
#  'madre',
#  'empac',
#  'bogot',
#  'colombian',
#  'pornografi',
#  'bisexual',
#  'influ',
#  'independient',
#  'usarl',
#  'retir',
#  'ofrec',
#  'alcanz',
#  'ejerc',
#  'latex',
#  'homosexual',
#  'ansied',
#  'vari',
#  'acc',
#  'implic',
#  'virg',
#  'primer',
#  'alcohol',
#  'ejercici',
#  'tranquil',
#  'trasmision',
#  'bienest',
#  'pubert',
#  'tampon',
#  'coito',
#  'maner',
#  'aparicion',
#  'extern',
#  'objetiv',
#  'vello',
#  'indic',
#  'fecund',
#  'caracterist',
#  'hongo',
#  'volv',
#  'inquietud',
#  'ovari',
#  'brind',
#  'nervio',
#  'frecuenci',
#  'libert',
#  'intimid',
#  'romant',
#  'anill',
#  'fecundacion',
#  'interrump',
#  'presenci',
#  'verific',
#  'punto',
#  'ropa',
#  'complic',
#  'reconoc',
#  'bacteri',
#  'claro',
#  'copar',
#  'hepatiti',
#  'verrug',
#  'insercion',
#  'dispon',
#  'fecho',
#  'evalu',
#  'capac',
#  'gland',
#  'diagnostic',
#  'promov',
#  'deberi',
#  'pesar',
#  'objet',
#  'aguar',
#  'motiv',
#  'boca',
#  'amor',
#  'ubic',
#  'facilit',
#  'dar',
#  'alergi',
#  'ovulacion',
#  'principal',
#  'costo',
#  'creenci',
#  'personaliz',
#  'crec',
#  'pequen',
#  'liber',
#  'ambient',
#  'paso',
#  'violacion',
#  'public',
#  'probabl',
#  'aclar',
#  'demor',
#  'ligadur',
#  'favorec',
#  'posicion',
#  'cientif',
#  'manch',
#  'espermic',
#  'consist',
#  'clinic',
#  'prefer',
#  'fluir',
#  'penetr',
#  'cabez',
#  'parch',
#  'continu',
#  'pelvic',
#  'limit',
#  'forz',
#  'permanent',
#  'polici',
#  'serio',
#  'tom',
#  'nau',
#  'laboratori',
#  'evidenci',
#  'escog',
#  'pudr',
#  'reproductor',
#  'inten',
#  'seleccion',
#  'satisfaccion',
#  'enlaz',
#  'vivenci',
#  'abdom',
#  'falto',
#  'introduc',
#  'acerc',
#  'serv',
#  'espaci',
#  'peligr',
#  'cubr',
#  'remit',
#  'sentenci',
#  'nino',
#  'expr',
#  'abund',
#  'definit',
#  'celul',
#  'increment',
#  'quirurg',
#  'sentimient',
#  'sensacion',
#  'mano',
#  'mayor',
#  'priv',
#  'accion',
#  'histori',
#  'prest',
#  'anormal',
#  'uretr',
#  'cuid',
#  'dano',
#  'oblig',
#  'amigo',
#  'planificacion',
#  'insert',
#  'observ',
#  'precoz',
#  'respond',
#  'irregul',
#  'simpl',
#  'drog',
#  'involucr',
#  'sufr',
#  'urinari',
#  'obligacion',
#  'vulva',
#  'besar',
#  'agresor',
#  'fiscali',
#  'formul',
#  'compr',
#  'reduc',
#  'confiabl',
#  'mensual',
#  'aplic',
#  'irregular',
#  'ciclo',
#  'realizart',
#  'consum',
#  'denomin',
#  'urgenci',
#  'ruptur',
#  'tocar',
#  'ideo',
#  'correspond',
#  'gusto',
#  'dema',
#  'facil',
#  'urologi',
#  'area',
#  'herir',
#  'concept',
#  'who',
#  'aconsej',
#  'numer',
#  'suspend',
#  'muco',
#  'utiliz',
#  'ultim',
#  'disfuncion',
#  'miedo',
#  'blanc',
#  'enrojec',
#  'complet',
#  'via',
#  'diari',
#  'afili',
#  'caja',
#  'plazo',
#  'orifici',
#  'institu',
#  'exig',
#  'prostat',
#  'clitori',
#  'hac',
#  'escrot',
#  'común',
#  'profilaxi',
#  'pubic',
#  'int',
#  'rap',
#  'relaj',
#  'elimin',
#  'integr',
#  'feto',
#  'ardor',
#  'direct',
#  'gonorre',
#  'fuert',
#  'pdf',
#  'particul',
#  'leche',
#  'mutuo',
#  'comunic',
#  'constitucional',
#  'heterosexual',
#  'matern',
#  'comet',
#  'interior',
#  'cervix',
#  'codig',
#  'regular',
#  'adapt',
#  'promedi',
#  'eficaci',
#  'autonom',
#  'disminucion',
#  'consider',
#  'ginecologi',
#  'intern',
#  'grati',
#  'irritacion',
#  'erectil',
#  'infertil',
#  'sencill',
#  'sensibl',
#  'tran',
#  'sano',
#  'mamar',
#  'posit',
#  'nacional',
#  'venir',
#  'parec',
#  'gestacion',
#  'seguimient',
#  'fantasi',
#  'inmunodeficient',
#  'identificart',
#  'articul',
#  'preci',
#  'mediacentr',
#  'factsheet',
#  'util',
#  'consensu',
#  'doler',
#  'realid',
#  'estrategi',
#  'conduct',
#  'existent',
#  'rozar',
#  'habitual',
#  'desaparec',
#  'juego',
#  'sentirt',
#  'minim',
#  'pensamient',
#  'ministeri',
#  'ritm',
#  'particip',
#  'especif',
#  'trastorn',
#  'ectop',
#  'glandul',
#  'material',
#  'cercan',
#  'lgbti',
#  'pezón',
#  'asesorart',
#  'preseminal',
#  'esteril',
#  'instruccion',
#  'caser',
#  'orden',
#  'erect',
#  'fase',
#  'muert',
#  'genet',
#  'poblacion',
#  'senal',
#  'durar',
#  'emocion',
#  'encarg',
#  'component',
#  'ovul',
#  'simil',
#  'mocar',
#  'asign',
#  'primari',
#  'parasit',
#  'violent',
#  'crema',
#  'desplaz',
#  'picazon',
#  'penal',
#  'asum',
#  'corto',
#  'ilegal',
#  'opon',
#  'porno',
#  'rutinari',
#  'list',
#  'pleno',
#  'autorizacion',
#  'mencion',
#  'interfer',
#  'prolong',
#  'contribu',
#  'vomit',
#  'confirm',
#  'repet',
#  'orientart',
#  'soler',
#  'pelvi',
#  'cronic',
#  'proposit',
#  'real',
#  'membran',
#  'entreg',
#  'fabric',
#  'eleccion',
#  'cervical',
#  'preferent',
#  'actu',
#  'cabo',
#  'intercambi',
#  'calid',
#  'involuntari',
#  'lactanci',
#  'falso',
#  'ginecolog',
#  'mecan',
#  'ampoll',
#  'satisfactori',
#  'gay',
#  'termin',
#  'convivent',
#  'vulner',
#  'telefon',
#  'librement',
#  'cultural',
#  'discriminacion',
#  'icbf',
#  'unic',
#  'antibiot',
#  'exclu',
#  'planific',
#  'expul',
#  'inyeccion',
#  'centimetr',
#  'tecnic',
#  'persist',
#  'asegur',
#  'colic',
#  'fallo',
#  'combin',
#  'vaya',
#  'pre',
#  'retr',
#  'depresion',
#  'diabet',
#  'seri',
#  'raza',
#  'dispareuni',
#  'com',
#  'agrad',
#  'vejig',
#  'percib',
#  'notar',
#  'super',
#  'acept',
#  'culp',
#  'clamidi',
#  'administr',
#  'acercart',
#  'honest',
#  'darte',
#  'mundial',
#  'cobr',
#  'sciel',
#  'lesbian',
#  'alerg',
#  'menopausi',
#  'punta',
#  'autonomi',
#  'exposicion',
#  'invim',
#  'curar',
#  'aparient',
#  'aco',
#  'desnud',
#  'bucal',
#  'agresion',
#  'amenaz',
#  'foto',
#  'purpur',
#  'rol',
#  'prostitucion',
#  'nombr',
#  'constant',
#  'retorn',
#  'modific',
#  'temporal',
#  'brazo',
#  'circuncision',
#  'exc',
#  'estructur',
#  'noto',
#  'histerectomi',
#  'intervencion',
#  'coital',
#  'grad',
#  'rapid',
#  'alteracion',
#  'solucion',
#  'transicion',
#  'variabl',
#  'estrogen',
#  'modern',
#  'recomendacion',
#  'manifest',
#  'organizacion',
#  'acne',
#  'anatom',
#  'squirt',
#  'detall',
#  'influenci',
#  'carg',
#  'humed',
#  'frenill',
#  'lavar',
#  'moment',
#  'preocup',
#  'malform',
#  'ips',
#  'religion',
#  'ulcer',
#  'deten',
#  'expect',
#  'fiebr',
#  'comisari',
#  'adopcion',
#  'econom',
#  'fetich',
#  'usar',
#  'total',
#  'medio',
#  'ven',
#  'seminal',
#  'fimosi',
#  'deb',
#  'retard',
#  'inger',
#  'despej',
#  'traum',
#  'hinchazon',
#  'contraccion',
#  'benign',
#  'discut',
#  'vincul',
#  'tomart',
#  'consistent',
#  'oms',
#  'norma',
#  'resolucion',
#  'mito',
#  'garanti',
#  'cicatriz',
#  'adopt',
#  'malest',
#  'abraz',
#  'cent',
#  'traer',
#  'afor',
#  'sacar',
#  'merc',
#  'regim',
#  'aceit',
#  'manir',
#  'raro',
#  'regl',
#  'esp',
#  'intim',
#  'visit',
#  'surg',
#  'irrit',
#  'inflamatori',
#  'autor',
#  'parar',
#  'erogen',
#  'estacion',
#  'interpret',
#  'indigen',
#  'farmaci',
#  'actua',
#  'unir',
#  'interaccion',
#  'incapac',
#  'recur',
#  'complementari',
#  'transparent',
#  'sonar',
#  'extrem',
#  'asistent',
#  'golpe',
#  'tijer',
#  'tej',
#  'imag',
#  'autoestim',
#  'percepcion',
#  'posibl',
#  'progestagen',
#  'educ',
#  'rolar',
#  'abstinent',
#  'promocion',
#  'fortalec',
#  'confidencial',
#  'requisit',
#  'afiliacion',
#  'document',
#  'rod',
#  'juzg',
#  'terapi',
#  'ten',
#  'especializ',
#  'clase',
#  'lacer',
#  'align',
#  'height',
#  'manifiest',
#  'org',
#  'sindrom',
#  'sujet',
#  'comprend',
#  'limpi',
#  'actual',
#  'ventaj',
#  'conversacion',
#  'danar',
#  'delg',
#  'concienci',
#  'deteccion',
#  'vacunacion',
#  'carnal',
#  'implantacion',
#  'diafragm',
#  'cancer',
#  'potenci',
#  'asexual',
#  'mensaj',
#  'crear',
#  'religi',
#  'program',
#  'lenguaj',
#  'exploracion',
#  'mont',
#  'graved',
#  'anorgasmi',
#  'explotacion',
#  'recubr',
#  'reaccion',
#  'redar',
#  'cost',
#  'recibir',
#  'amenorre',
#  'estil',
#  'adver',
#  'exact',
#  'neurolog',
#  'curvatur',
#  'nervi',
#  'papel',
#  'extraccion',
#  'falopi',
#  'mundo',
#  'masaj',
#  'relajacion',
#  'trabaj',
#  'recurrent',
#  'tard',
#  'preparacion',
#  'enter',
#  'flexibl',
#  'trimestral',
#  'caro',
#  'daran',
#  'hospital',
#  'transexual',
#  'ets',
#  'inicial',
#  'impotent',
#  'cavid',
#  'indispen',
#  'conllev',
#  'constitu',
#  'guard',
#  'protector',
#  'amarill',
#  'comezon',
#  'alivi',
#  'deposicion',
#  'friccion',
#  'sancion',
#  'muestr',
#  'exterior',
#  'cheque',
#  'nina',
#  'inviabl',
#  'negar',
#  'entorn',
#  'nocturn',
#  'anim',
#  'enfrent',
#  'verbal',
#  'visual',
#  'explicit',
#  'penaliz',
#  'atent',
#  'fotografi',
#  'queer',
#  'internet',
#  'context',
#  'voyer',
#  'enamor',
#  'digital',
#  'vaginiti',
#  'maltrat',
#  'insegur',
#  'hipersexual',
#  'drag',
#  'evident',
#  'pon',
#  'deber',
#  'tradicional',
#  'html',
#  'finar',
#  'investigacion',
#  'recuper',
#  'esterilizacion',
#  'retom',
#  'contraindicacion',
#  'reforz',
#  'cienci',
#  'adelant',
#  'vena',
#  'recto',
#  'liberacion',
#  'antecedent',
#  'agudo',
#  'duch',
#  'gov',
#  'valid',
#  'ayudart',
#  'dara',
#  'persistent',
#  'cerebr',
#  'estir',
#  'germen',
#  'habil',
#  'deriv',
#  'actitud',
#  'amig',
#  'avanz',
#  'diarre',
#  'grav',
#  ...]

# %%
import pickle
with open("corpus_sexperto_with_stemming_vector.pkl", 'wb') as fio_corpus:
    pickle.dump([c[0] for c in common_words], fio_corpus)

# %%
ret = []
for icm in range(len(common_words)):
    dic = {'word':common_words[icm][0]}
    dic["child"] = [item[0] for item in model.wv.most_similar(common_words[icm][0], topn=20)]
    ret.append(dic)
len(ret)
# Out:
# 100

# %%
ret
# Out:
# [{'word': 'sexual',
#   'child': ['relacionar',
#    'parejo',
#    'disfrutar',
#    'relacion',
#    'adquirir',
#    'practicar',
#    'significar',
#    'gustar',
#    'respetar',
#    'vih',
#    'consentimiento',
#    'contactar',
#    'identificar',
#    'querer',
#    'acto',
#    'anal',
#    'comunicacion',
#    'placentero',
#    'orientacion',
#    'compartir']},
#  {'word': 'relacionar',
#   'child': ['adquirir',
#    'sexual',
#    'contactar',
#    'significar',
#    'comunicacion',
#    'its',
#    'transmitir',
#    'presion',
#    'respetar',
#    'incluir',
#    'consentimiento',
#    'compartir',
#    'relacion',
#    'actividad',
#    'ayudar',
#    'diferenciar',
#    'definir',
#    'establecer',
#    'protegerte',
#    'malo']},
#  {'word': 'personar',
#   'child': ['atraccion',
#    'sentir',
#    'sexo',
#    'parejo',
#    'orientacion',
#    'practicar',
#    'gustar',
#    'placer',
#    'disfrutar',
#    'identificar',
#    'acto',
#    'sexual',
#    'querer',
#    'sexualidad',
#    'excitacion',
#    'relacion',
#    'consentimiento',
#    'respetar',
#    'orgasmo',
#    'resultar']},
#  {'word': 'salud',
#   'child': ['asesoria',
#    'centrar',
#    'asistir',
#    'citar',
#    'recomer',
#    'solicitar',
#    'anticoncepcion',
#    'atencion',
#    'recibir',
#    'consultar',
#    'asesorar',
#    'entidad',
#    'eps',
#    'dudar',
#    'necesidad',
#    'medicar',
#    'gratuito',
#    'valoracion',
#    'poder',
#    'garantizar']},
#  {'word': 'embarazar',
#   'child': ['regular',
#    'hormonal',
#    'pildora',
#    'metodo',
#    'largo',
#    'intrauterino',
#    'efecto',
#    'disminuir',
#    'efectividad',
#    'tomar',
#    'mes',
#    'implantar',
#    'menstruacion',
#    'diu',
#    'emergencia',
#    'dispositivo',
#    'duracion',
#    'primero',
#    'doblar',
#    'hormona']},
#  {'word': 'condon',
#   'child': ['infección',
#    'prevenir',
#    'unico',
#    'embarazo',
#    'transmision',
#    'proteger',
#    'prevencion',
#    'protegerte',
#    'doblar',
#    'adecuar',
#    'barrera',
#    'planear',
#    'largo',
#    'descartar',
#    'recomendar',
#    'its',
#    'dudar',
#    'preservativo',
#    'infeccion',
#    'adicionalmente']},
#  {'word': 'anticonceptivo',
#   'child': ['pastilla',
#    'emergencia',
#    'metodo',
#    'pildora',
#    'hormonal',
#    'efecto',
#    'efectividad',
#    'tomar',
#    'anticoncepcion',
#    'embarazar',
#    'regular',
#    'implantar',
#    'entidad',
#    'menstruacion',
#    'asistir',
#    'necesidad',
#    'asesorar',
#    'citar',
#    'recomer',
#    'asesoria']},
#  {'word': 'infección',
#   'child': ['transmision',
#    'condon',
#    'unico',
#    'proteger',
#    'infeccion',
#    'enfermedad',
#    'barrera',
#    'prevenir',
#    'embarazo',
#    'prevencion',
#    'protegerte',
#    'preservativo',
#    'doblar',
#    'contagiar',
#    'sifili',
#    'its',
#    'planear',
#    'condonar',
#    'descartar',
#    'largo']},
#  {'word': 'poder',
#   'child': ['especificar',
#    'eps',
#    'garantizar',
#    'acudir',
#    'requerir',
#    'medicar',
#    'linear',
#    'recibir',
#    'dudar',
#    'gratuito',
#    'adecuar',
#    'comunicarte',
#    'solicitar',
#    'temer',
#    'consultar',
#    'valorar',
#    'bogota',
#    'seguro',
#    'situacion',
#    'social']},
#  {'word': 'transmision',
#   'child': ['infección',
#    'proteger',
#    'condon',
#    'unico',
#    'infeccion',
#    'enfermedad',
#    'barrera',
#    'preservativo',
#    'prevenir',
#    'contagiar',
#    'prevencion',
#    'vih',
#    'sida',
#    'embarazo',
#    'doblar',
#    'trasmision',
#    'protegerte',
#    'sifili',
#    'adquirir',
#    'its']},
#  {'word': 'asistir',
#   'child': ['citar',
#    'anticoncepcion',
#    'asesoria',
#    'entidad',
#    'salud',
#    'recomer',
#    'asesorar',
#    'necesidad',
#    'centrar',
#    'solicitar',
#    'consultar',
#    'dudar',
#    'atencion',
#    'recibir',
#    'eps',
#    'metodo',
#    'gratuito',
#    'prevenir',
#    'medicar',
#    'emergencia']},
#  {'word': 'parejo',
#   'child': ['practicar',
#    'gustar',
#    'disfrutar',
#    'identificar',
#    'placer',
#    'relacion',
#    'excitacion',
#    'atraccion',
#    'placentero',
#    'resultar',
#    'significar',
#    'acto',
#    'malo',
#    'consentimiento',
#    'orientacion',
#    'relacionar',
#    'respetar',
#    'orgasmo',
#    'sexual',
#    'querer']},
#  {'word': 'recomer',
#   'child': ['asesoria',
#    'centrar',
#    'salud',
#    'asistir',
#    'recibir',
#    'solicitar',
#    'atencion',
#    'prevenir',
#    'valoracion',
#    'dudar',
#    'consultar',
#    'asesorar',
#    'medicar',
#    'anticoncepcion',
#    'citar',
#    'eps',
#    'adecuar',
#    'efectividad',
#    'regular',
#    'necesidad']},
#  {'word': 'anticoncepcion',
#   'child': ['citar',
#    'asistir',
#    'asesoria',
#    'entidad',
#    'salud',
#    'asesorar',
#    'necesidad',
#    'recomer',
#    'centrar',
#    'solicitar',
#    'metodo',
#    'dudar',
#    'consultar',
#    'emergencia',
#    'recibir',
#    'atencion',
#    'eps',
#    'prevenir',
#    'gratuito',
#    'regular']},
#  {'word': 'consultar',
#   'child': ['eps',
#    'dudar',
#    'solicitar',
#    'recibir',
#    'gratuito',
#    'atencion',
#    'asesorar',
#    'medicar',
#    'poder',
#    'garantizar',
#    'especificar',
#    'adecuar',
#    'necesidad',
#    'valoracion',
#    'siguiente',
#    'asesoria',
#    'recomendar',
#    'requerir',
#    'contenido',
#    'acudir']},
#  {'word': 'ano',
#   'child': ['tratar',
#    'familiar',
#    'adolescente',
#    'condonar',
#    'vacuno',
#    'uterino',
#    'acceder',
#    'vph',
#    'fertilidad',
#    'responsable',
#    'madre',
#    'alto',
#    'medicinar',
#    'papiloma',
#    'trompa',
#    'latex',
#    'bogota',
#    'vasectomia',
#    'humanar',
#    'razon']},
#  {'word': 'sentir',
#   'child': ['sexo',
#    'atraccion',
#    'personar',
#    'practicar',
#    'parejo',
#    'placer',
#    'gustar',
#    'orientacion',
#    'excitacion',
#    'identificar',
#    'disfrutar',
#    'orgasmo',
#    'relacion',
#    'anal',
#    'acto',
#    'resultar',
#    'penar',
#    'normal',
#    'querer',
#    'estimulacion']},
#  {'word': 'relacion',
#   'child': ['placentero',
#    'significar',
#    'gustar',
#    'malo',
#    'estimulacion',
#    'contactar',
#    'actividad',
#    'excitacion',
#    'masturbacion',
#    'conocer',
#    'identificar',
#    'placer',
#    'disfrutar',
#    'referir',
#    'practicar',
#    'presion',
#    'comunicacion',
#    'resultar',
#    'orgasmo',
#    'penetracion']},
#  {'word': 'casar',
#   'child': ['probar',
#    'mesar',
#    'especificar',
#    'seguro',
#    'medicar',
#    'valoracion',
#    'adecuar',
#    'requerir',
#    'acudir',
#    'apropiar',
#    'situacion',
#    'desear',
#    'recomendar',
#    'descartar',
#    'iniciar',
#    'inmediato',
#    'examen',
#    'efectivo',
#    'adicionalmente',
#    'voluntario']},
#  {'word': 'tomar',
#   'child': ['efectividad',
#    'implantar',
#    'regular',
#    'medicamento',
#    'efecto',
#    'disminuir',
#    'embarazar',
#    'hormonal',
#    'subdermico',
#    'iniciar',
#    'pildora',
#    'metodo',
#    'emergencia',
#    'secundario',
#    'menstruacion',
#    'mes',
#    'hormona',
#    'efectivo',
#    'intrauterino',
#    'dispositivo']},
#  {'word': 'informacion',
#   'child': ['sexperto',
#    'acceder',
#    'necesidad',
#    'gratuito',
#    'trasmision',
#    'ano',
#    'invitar',
#    'siguiente',
#    'contenido',
#    'primero',
#    'latex',
#    'asesorar',
#    'tratar',
#    'valorar',
#    'bogota',
#    'proteger',
#    'dudar',
#    'temer',
#    'garantizar',
#    'barrera']},
#  {'word': 'presentar',
#   'child': ['dolor',
#    'liquidar',
#    'problema',
#    'sangrar',
#    'seno',
#    'semen',
#    'cantidad',
#    'orinar',
#    'testiculo',
#    'alteración',
#    'tamano',
#    'ocasionar',
#    'piel',
#    'algun',
#    'molestia',
#    'inflamacion',
#    'frecuentar',
#    'asociar',
#    'utero',
#    'normal']},
#  {'word': 'sexo',
#   'child': ['sentir',
#    'personar',
#    'atraccion',
#    'practicar',
#    'parejo',
#    'anal',
#    'placer',
#    'gustar',
#    'excitacion',
#    'identificar',
#    'relacion',
#    'orientacion',
#    'sexual',
#    'disfrutar',
#    'orgasmo',
#    'penar',
#    'penetracion',
#    'genital',
#    'placentero',
#    'masturbacion']},
#  {'word': 'derecho',
#   'child': ['reproductivo',
#    'colombia',
#    'violencia',
#    'victimar',
#    'ley',
#    'discapacidad',
#    'temer',
#    'edad',
#    'social',
#    'librar',
#    'hijo',
#    'denunciar',
#    'fundamental',
#    'legal',
#    'linear',
#    'querer',
#    'delito',
#    'acto',
#    'garantizar',
#    'apoyar']},
#  {'word': 'página',
#   'child': ['segundo',
#    'milisegundo',
#    'http',
#    'referenciar',
#    'informacion',
#    'trasmision',
#    'sexperto',
#    'latex',
#    'ano',
#    'proteger',
#    'preservativo',
#    'barrera',
#    'primero',
#    'infectar',
#    'tratar',
#    'virginidad',
#    'uterino',
#    'enfermedad',
#    'alto',
#    'acceder']},
#  {'word': 'medicar',
#   'child': ['valoracion',
#    'especificar',
#    'adecuar',
#    'recibir',
#    'requerir',
#    'casar',
#    'acudir',
#    'poder',
#    'dudar',
#    'probar',
#    'recomendar',
#    'eps',
#    'mesar',
#    'descartar',
#    'atencion',
#    'solicitar',
#    'consultar',
#    'garantizar',
#    'gratuito',
#    'apropiar']},
#  {'word': 'penar',
#   'child': ['eyaculacion',
#    'penetracion',
#    'excitacion',
#    'genital',
#    'normal',
#    'lubricacion',
#    'orgasmo',
#    'semen',
#    'estimulacion',
#    'ereccion',
#    'vagina',
#    'placer',
#    'liquidar',
#    'masturbacion',
#    'tamano',
#    'dolor',
#    'vaginal',
#    'relacion',
#    'femenino',
#    'practicar']},
#  {'word': 'causar',
#   'child': ['uterino',
#    'probabilidad',
#    'generalmente',
#    'organo',
#    'producto',
#    'bajo',
#    'sintoma',
#    'zona',
#    'enfermedad',
#    'herp',
#    'factor',
#    'lubricante',
#    'vph',
#    'papiloma',
#    'contagiar',
#    'razonar',
#    'doloroso',
#    'estudio',
#    'posibilidad',
#    'flujo']},
#  {'word': 'citar',
#   'child': ['anticoncepcion',
#    'asistir',
#    'entidad',
#    'asesoria',
#    'salud',
#    'asesorar',
#    'necesidad',
#    'recomer',
#    'solicitar',
#    'centrar',
#    'consultar',
#    'dudar',
#    'atencion',
#    'eps',
#    'recibir',
#    'gratuito',
#    'metodo',
#    'emergencia',
#    'prevenir',
#    'regular']},
#  {'word': 'infeccion',
#   'child': ['contagiar',
#    'enfermedad',
#    'adquirir',
#    'sida',
#    'transmitir',
#    'herp',
#    'sifili',
#    'vih',
#    'infectar',
#    'humanar',
#    'papiloma',
#    'vph',
#    'sintoma',
#    'condonar',
#    'its',
#    'tipo',
#    'uterino',
#    'lubricante',
#    'infección',
#    'preservativo']},
#  {'word': 'genital',
#   'child': ['lubricacion',
#    'vaginal',
#    'contactar',
#    'piel',
#    'penetracion',
#    'semen',
#    'liquidar',
#    'estimulacion',
#    'excitacion',
#    'ereccion',
#    'femenino',
#    'relacion',
#    'lesionar',
#    'inflamacion',
#    'eyacular',
#    'eyaculacion',
#    'placentero',
#    'estimular',
#    'normal',
#    'dolor']},
#  {'word': 'desear',
#   'child': ['seguro',
#    'situacion',
#    'ser',
#    'recomendable',
#    'consecuencia',
#    'condicionar',
#    'marcar',
#    'situación',
#    'fisico',
#    'its',
#    'decisión',
#    'etcétera',
#    'esperar',
#    'apropiar',
#    'emocional',
#    'manejar',
#    'social',
#    'acceso',
#    'incluir',
#    'voluntario']},
#  {'word': 'sangrar',
#   'child': ['presentar',
#    'alteración',
#    'menstrual',
#    'dolor',
#    'seno',
#    'ciclar',
#    'utero',
#    'cantidad',
#    'hormona',
#    'secundario',
#    'alterar',
#    'semana',
#    'problema',
#    'orinar',
#    'frecuente',
#    'retrasar',
#    'molestia',
#    'ovulo',
#    'frecuentar',
#    'espermatozoide']},
#  {'word': 'tipo',
#   'child': ['producto',
#    'razon',
#    'unica',
#    'empezar',
#    'factor',
#    'influir',
#    'existir',
#    'ver',
#    'organo',
#    'dejar',
#    'posibilidad',
#    'citologia',
#    'lubricante',
#    'herp',
#    'higiene',
#    'psicologico',
#    'razonar',
#    'vph',
#    'afectar',
#    'estudio']},
#  {'word': 'dolor',
#   'child': ['presentar',
#    'liquidar',
#    'lubricacion',
#    'tamano',
#    'piel',
#    'normal',
#    'seno',
#    'ereccion',
#    'inflamacion',
#    'orinar',
#    'cantidad',
#    'semen',
#    'problema',
#    'testiculo',
#    'utero',
#    'eyacular',
#    'flujo',
#    'alteración',
#    'femenino',
#    'vaginal']},
#  {'word': 'recibir',
#   'child': ['atencion',
#    'solicitar',
#    'eps',
#    'medicar',
#    'dudar',
#    'consultar',
#    'poder',
#    'valoracion',
#    'especificar',
#    'garantizar',
#    'gratuito',
#    'centrar',
#    'adecuar',
#    'requerir',
#    'asesorar',
#    'acudir',
#    'recomendar',
#    'asesoria',
#    'casar',
#    'probar']},
#  {'word': 'sexualidad',
#   'child': ['vida',
#    'disfrutar',
#    'discapacidad',
#    'significar',
#    'respetar',
#    'acto',
#    'compartir',
#    'malo',
#    'explorar',
#    'placentero',
#    'identificar',
#    'consentimiento',
#    'abusar',
#    'referir',
#    'humano',
#    'gustar',
#    'experiencia',
#    'querer',
#    'actividad',
#    'definir']},
#  {'word': 'adecuar',
#   'child': ['recomendar',
#    'requerir',
#    'especificar',
#    'descartar',
#    'embarazo',
#    'acudir',
#    'mesar',
#    'examen',
#    'medicar',
#    'apropiar',
#    'prevencion',
#    'efectivo',
#    'adicionalmente',
#    'inmediato',
#    'iniciar',
#    'valorar',
#    'probar',
#    'planear',
#    'empacar',
#    'correcto']},
#  {'word': 'prevenir',
#   'child': ['condon',
#    'embarazo',
#    'unico',
#    'adecuar',
#    'dudar',
#    'prevencion',
#    'recomendar',
#    'regular',
#    'infección',
#    'protegerte',
#    'asesorar',
#    'largo',
#    'doblar',
#    'descartar',
#    'especificar',
#    'medicar',
#    'planear',
#    'recomer',
#    'gratuito',
#    'efectivo']},
#  {'word': 'querer',
#   'child': ['consentimiento',
#    'respetar',
#    'acto',
#    'librar',
#    'establecer',
#    'definir',
#    'discapacidad',
#    'emocional',
#    'ley',
#    'identificar',
#    'incluir',
#    'ayudar',
#    'orientacion',
#    'vida',
#    'ejercer',
#    'disfrutar',
#    'ser',
#    'compartir',
#    'comunicacion',
#    'fisica']},
#  {'word': 'normal',
#   'child': ['estimulacion',
#    'excitacion',
#    'tamano',
#    'femenino',
#    'ereccion',
#    'orgasmo',
#    'eyacular',
#    'estimular',
#    'liquidar',
#    'lubricacion',
#    'conocer',
#    'semen',
#    'dolor',
#    'resultar',
#    'malo',
#    'cuerpo',
#    'masturbacion',
#    'eyaculacion',
#    'placentero',
#    'relacion']},
#  {'word': 'vaginal',
#   'child': ['lubricacion',
#    'genital',
#    'piel',
#    'contactar',
#    'penetracion',
#    'oral',
#    'dolor',
#    'liquidar',
#    'semen',
#    'vagina',
#    'inflamacion',
#    'lesionar',
#    'ereccion',
#    'femenino',
#    'flujo',
#    'eyacular',
#    'estimular',
#    'estimulacion',
#    'doloroso',
#    'normal']},
#  {'word': 'entidad',
#   'child': ['necesidad',
#    'citar',
#    'asistir',
#    'asesorar',
#    'anticoncepcion',
#    'asesoria',
#    'dudar',
#    'salud',
#    'gratuito',
#    'consultar',
#    'solicitar',
#    'metodo',
#    'eps',
#    'recomer',
#    'recibir',
#    'emergencia',
#    'centrar',
#    'atencion',
#    'regular',
#    'informacion']},
#  {'word': 'edad',
#   'child': ['ley',
#    'delito',
#    'discapacidad',
#    'legal',
#    'abusar',
#    'apoyar',
#    'colombiano',
#    'social',
#    'denunciar',
#    'librar',
#    'fundamental',
#    'decisión',
#    'humano',
#    'hijo',
#    'ejercer',
#    'ejercicio',
#    'vida',
#    'establecer',
#    'incluir',
#    'bienestar']},
#  {'word': 'atencion',
#   'child': ['recibir',
#    'solicitar',
#    'eps',
#    'centrar',
#    'consultar',
#    'dudar',
#    'medicar',
#    'poder',
#    'valoracion',
#    'garantizar',
#    'especificar',
#    'asesoria',
#    'gratuito',
#    'salud',
#    'recomer',
#    'adecuar',
#    'asesorar',
#    'requerir',
#    'acudir',
#    'casar']},
#  {'word': 'hormonal',
#   'child': ['efecto',
#    'pildora',
#    'embarazar',
#    'menstruacion',
#    'efectividad',
#    'metodo',
#    'implantar',
#    'tomar',
#    'emergencia',
#    'intrauterino',
#    'regular',
#    'diu',
#    'disminuir',
#    'periodo',
#    'dispositivo',
#    'hormona',
#    'subdermico',
#    'secundario',
#    'medicamento',
#    'largo']},
#  {'word': 'practicar',
#   'child': ['parejo',
#    'gustar',
#    'placer',
#    'excitacion',
#    'relacion',
#    'identificar',
#    'disfrutar',
#    'orgasmo',
#    'placentero',
#    'resultar',
#    'estimulacion',
#    'atraccion',
#    'malo',
#    'significar',
#    'contactar',
#    'masturbacion',
#    'acto',
#    'semen',
#    'respetar',
#    'genital']},
#  {'word': 'metodo',
#   'child': ['emergencia',
#    'regular',
#    'pildora',
#    'embarazar',
#    'efectividad',
#    'hormonal',
#    'tomar',
#    'efecto',
#    'largo',
#    'intrauterino',
#    'asesorar',
#    'implantar',
#    'necesidad',
#    'doblar',
#    'disminuir',
#    'primero',
#    'medicamento',
#    'recomendar',
#    'subdermico',
#    'diu']},
#  {'word': 'vida',
#   'child': ['discapacidad',
#    'humano',
#    'respetar',
#    'abusar',
#    'compartir',
#    'delito',
#    'sexualidad',
#    'explorar',
#    'librar',
#    'establecer',
#    'edad',
#    'consentimiento',
#    'definir',
#    'fisica',
#    'ejercer',
#    'pornografia',
#    'significar',
#    'experiencia',
#    'referir',
#    'ley']},
#  {'word': 'asesoria',
#   'child': ['salud',
#    'asistir',
#    'recomer',
#    'anticoncepcion',
#    'citar',
#    'centrar',
#    'asesorar',
#    'solicitar',
#    'entidad',
#    'atencion',
#    'dudar',
#    'necesidad',
#    'consultar',
#    'recibir',
#    'eps',
#    'gratuito',
#    'prevenir',
#    'medicar',
#    'metodo',
#    'regular']},
#  {'word': 'pastilla',
#   'child': ['emergencia',
#    'anticonceptivo',
#    'pildora',
#    'efecto',
#    'hormonal',
#    'metodo',
#    'efectividad',
#    'tomar',
#    'embarazar',
#    'menstruacion',
#    'implantar',
#    'regular',
#    'periodo',
#    'intrauterino',
#    'disminuir',
#    'medicamento',
#    'subdermico',
#    'hormona',
#    'diu',
#    'secundario']},
#  {'word': 'oral',
#   'child': ['vaginal',
#    'piel',
#    'contactar',
#    'lubricacion',
#    'genital',
#    'lesionar',
#    'inflamacion',
#    'flujo',
#    'liquidar',
#    'asociar',
#    'femenino',
#    'semen',
#    'estimular',
#    'posibilidad',
#    'orinar',
#    'algun',
#    'eyacular',
#    'especialmente',
#    'dolor',
#    'lubricante']},
#  {'word': 'iniciar',
#   'child': ['efectivo',
#    'recomendar',
#    'mesar',
#    'mes',
#    'disminuir',
#    'correcto',
#    'duracion',
#    'inmediato',
#    'semana',
#    'medicamento',
#    'empacar',
#    'subdermico',
#    'probar',
#    'regular',
#    'largo',
#    'adecuar',
#    'requerir',
#    'descartar',
#    'adicionalmente',
#    'dispositivo']},
#  {'word': 'vagina',
#   'child': ['penetracion',
#    'lubricacion',
#    'himen',
#    'cuerpo',
#    'ereccion',
#    'masturbacion',
#    'genital',
#    'vaginal',
#    'zona',
#    'virginidad',
#    'estimulacion',
#    'penar',
#    'eyacular',
#    'eyaculacion',
#    'femenino',
#    'contactar',
#    'normal',
#    'virgen',
#    'tamano',
#    'piel']},
#  {'word': 'menstrual',
#   'child': ['ciclar',
#    'menstruacion',
#    'sangrar',
#    'secundario',
#    'hormona',
#    'periodo',
#    'medicamento',
#    'implantar',
#    'disminuir',
#    'alteración',
#    'dispositivo',
#    'diu',
#    'subdermico',
#    'semana',
#    'seno',
#    'mes',
#    'ovulo',
#    'efecto',
#    'utero',
#    'tomar']},
#  {'word': 'cuerpo',
#   'child': ['zona',
#    'masturbacion',
#    'himen',
#    'virginidad',
#    'virgen',
#    'conocer',
#    'empezar',
#    'ereccion',
#    'placentero',
#    'estimular',
#    'estimulacion',
#    'experimentar',
#    'factor',
#    'influir',
#    'actividad',
#    'doloroso',
#    'femenino',
#    'organo',
#    'referir',
#    'masculino']},
#  {'word': 'efecto',
#   'child': ['hormonal',
#    'pildora',
#    'menstruacion',
#    'implantar',
#    'tomar',
#    'efectividad',
#    'embarazar',
#    'emergencia',
#    'periodo',
#    'metodo',
#    'regular',
#    'disminuir',
#    'hormona',
#    'secundario',
#    'intrauterino',
#    'subdermico',
#    'diu',
#    'medicamento',
#    'pastilla',
#    'dispositivo']},
#  {'word': 'vih',
#   'child': ['adquirir',
#    'sida',
#    'transmitir',
#    'infeccion',
#    'infectar',
#    'contagiar',
#    'herp',
#    'sifili',
#    'contactar',
#    'enfermedad',
#    'relacionar',
#    'humano',
#    'virgen',
#    'humanar',
#    'responsable',
#    'papiloma',
#    'tipo',
#    'its',
#    'madre',
#    'tratar']},
#  {'word': 'enfermedad',
#   'child': ['contagiar',
#    'herp',
#    'infeccion',
#    'preservativo',
#    'sida',
#    'uterino',
#    'infectar',
#    'sifili',
#    'papiloma',
#    'humanar',
#    'vph',
#    'barrera',
#    'causar',
#    'probabilidad',
#    'condonar',
#    'latex',
#    'transmitir',
#    'generalmente',
#    'producto',
#    'adecuadamente']},
#  {'word': 'menstruacion',
#   'child': ['periodo',
#    'efecto',
#    'menstrual',
#    'hormona',
#    'hormonal',
#    'secundario',
#    'implantar',
#    'ciclar',
#    'disminuir',
#    'embarazar',
#    'diu',
#    'dispositivo',
#    'tomar',
#    'intrauterino',
#    'subdermico',
#    'medicamento',
#    'pildora',
#    'mes',
#    'ovulo',
#    'efectividad']},
#  {'word': 'sexperto',
#   'child': ['informacion',
#    'acceder',
#    'invitar',
#    'contenido',
#    'siguiente',
#    'ano',
#    'bogota',
#    'tratar',
#    'gratuito',
#    'trasmision',
#    'temer',
#    'latex',
#    'primero',
#    'adolescente',
#    'valorar',
#    'condonar',
#    'medicinar',
#    'familiar',
#    'necesidad',
#    'barrera']},
#  {'word': 'segundo',
#   'child': ['milisegundo',
#    'página',
#    'http',
#    'referenciar',
#    'informacion',
#    'trasmision',
#    'sexperto',
#    'latex',
#    'ano',
#    'proteger',
#    'preservativo',
#    'barrera',
#    'primero',
#    'infectar',
#    'tratar',
#    'virginidad',
#    'uterino',
#    'enfermedad',
#    'alto',
#    'acceder']},
#  {'word': 'problema',
#   'child': ['algun',
#    'molestia',
#    'ocasionar',
#    'asociar',
#    'llamar',
#    'olor',
#    'frecuentar',
#    'dificultar',
#    'especialmente',
#    'flujo',
#    'cantidad',
#    'orinar',
#    'ansiedad',
#    'prepucio',
#    'estr',
#    'frecuente',
#    'lesionar',
#    'caso',
#    'inflamacion',
#    'sustanciar']},
#  {'word': 'sintoma',
#   'child': ['sifili',
#    'flujo',
#    'asociar',
#    'olor',
#    'generalmente',
#    'molestia',
#    'sistema',
#    'bajo',
#    'haber',
#    'inflamacion',
#    'lesionar',
#    'retrasar',
#    'higiene',
#    'lubricante',
#    'frecuente',
#    'colocar',
#    'producto',
#    'especialmente',
#    'prepucio',
#    'frecuentar']},
#  {'word': 'emergencia',
#   'child': ['pildora',
#    'metodo',
#    'pastilla',
#    'hormonal',
#    'efectividad',
#    'efecto',
#    'embarazar',
#    'tomar',
#    'regular',
#    'anticonceptivo',
#    'implantar',
#    'menstruacion',
#    'disminuir',
#    'intrauterino',
#    'medicamento',
#    'largo',
#    'asesorar',
#    'necesidad',
#    'primero',
#    'subdermico']},
#  {'word': 'eyaculacion',
#   'child': ['semen',
#    'orgasmo',
#    'penar',
#    'excitacion',
#    'liquidar',
#    'estimulacion',
#    'normal',
#    'lubricacion',
#    'penetracion',
#    'genital',
#    'ereccion',
#    'eyacular',
#    'femenino',
#    'dolor',
#    'tamano',
#    'presentar',
#    'masturbacion',
#    'placer',
#    'vagina',
#    'estimular']},
#  {'word': 'orientacion',
#   'child': ['querer',
#    'acto',
#    'identificar',
#    'consentimiento',
#    'gustar',
#    'disfrutar',
#    'respetar',
#    'atraccion',
#    'parejo',
#    'violencia',
#    'discapacidad',
#    'vida',
#    'ley',
#    'librar',
#    'victimar',
#    'definir',
#    'practicar',
#    'resultar',
#    'sexualidad',
#    'significar']},
#  {'word': 'violencia',
#   'child': ['victimar',
#    'ley',
#    'acto',
#    'discapacidad',
#    'colombia',
#    'delito',
#    'denunciar',
#    'edad',
#    'librar',
#    'querer',
#    'abusar',
#    'consentimiento',
#    'social',
#    'legal',
#    'temer',
#    'vida',
#    'respetar',
#    'apoyar',
#    'establecer',
#    'ayudar']},
#  {'word': 'ayudar',
#   'child': ['establecer',
#    'fisica',
#    'ser',
#    'compartir',
#    'emocional',
#    'ejercer',
#    'condicion',
#    'pornografia',
#    'obtener',
#    'apoyar',
#    'comunicacion',
#    'definir',
#    'implicar',
#    'bienestar',
#    'situación',
#    'librar',
#    'ejercicio',
#    'incluir',
#    'condicionar',
#    'explorar']},
#  {'word': 'encontrar',
#   'child': ['llamar',
#    'nivel',
#    'alcanzar',
#    'estr',
#    'dificultar',
#    'especialmente',
#    'dejar',
#    'obtener',
#    'ansiedad',
#    'ocasionar',
#    'sustanciar',
#    'negativo',
#    'afectar',
#    'frecuentar',
#    'situación',
#    'cirugia',
#    'prepucio',
#    'condicion',
#    'ver',
#    'etcétera']},
#  {'word': 'siguiente',
#   'child': ['contenido',
#    'invitar',
#    'bogota',
#    'medicinar',
#    'temer',
#    'linear',
#    'acudir',
#    'beneficio',
#    'comunicarte',
#    'acceder',
#    'recomendación',
#    'garantizar',
#    'valorar',
#    'joven',
#    'requerir',
#    'manejar',
#    'voluntario',
#    'adolescente',
#    'acceso',
#    'vasectomia']},
#  {'word': 'caso',
#   'child': ['ocasionar',
#    'fisico',
#    'ansiedad',
#    'llamar',
#    'algun',
#    'situación',
#    'estr',
#    'encontrar',
#    'negativo',
#    'resultar',
#    'obtener',
#    'dificultar',
#    'condicion',
#    'emocional',
#    'nivel',
#    'etcétera',
#    'consecuencia',
#    'especialmente',
#    'frecuentar',
#    'alcanzar']},
#  {'word': 'reproductivo',
#   'child': ['derecho',
#    'colombia',
#    'garantizar',
#    'victimar',
#    'temer',
#    'social',
#    'ley',
#    'abortar',
#    'linear',
#    'poder',
#    'fundamental',
#    'violencia',
#    'edad',
#    'denunciar',
#    'legal',
#    'librar',
#    'discapacidad',
#    'bogota',
#    'apoyar',
#    'decisión']},
#  {'word': 'necesidad',
#   'child': ['asesorar',
#    'entidad',
#    'gratuito',
#    'dudar',
#    'consultar',
#    'asesoria',
#    'eps',
#    'solicitar',
#    'metodo',
#    'regular',
#    'garantizar',
#    'acceder',
#    'asistir',
#    'recibir',
#    'citar',
#    'primero',
#    'valorar',
#    'anticoncepcion',
#    'doblar',
#    'planear']},
#  {'word': 'femenino',
#   'child': ['eyacular',
#    'estimular',
#    'estimulacion',
#    'masculino',
#    'conocer',
#    'liquidar',
#    'ereccion',
#    'nivel',
#    'estr',
#    'semen',
#    'dificultar',
#    'inflamacion',
#    'ocasionar',
#    'llamar',
#    'actividad',
#    'experimentar',
#    'lubricacion',
#    'tamano',
#    'normal',
#    'cantidad']},
#  {'word': 'penetracion',
#   'child': ['lubricacion',
#    'genital',
#    'vagina',
#    'masturbacion',
#    'vaginal',
#    'estimulacion',
#    'relacion',
#    'contactar',
#    'penar',
#    'excitacion',
#    'placentero',
#    'ereccion',
#    'eyaculacion',
#    'placer',
#    'semen',
#    'normal',
#    'cuerpo',
#    'orgasmo',
#    'femenino',
#    'liquidar']},
#  {'word': 'proteger',
#   'child': ['unico',
#    'barrera',
#    'preservativo',
#    'transmision',
#    'infección',
#    'trasmision',
#    'doblar',
#    'enfermedad',
#    'condon',
#    'prevencion',
#    'planear',
#    'condonar',
#    'infeccion',
#    'latex',
#    'embarazo',
#    'sida',
#    'contagiar',
#    'tratar',
#    'ano',
#    'acceder']},
#  {'word': 'probar',
#   'child': ['mesar',
#    'recomendar',
#    'requerir',
#    'casar',
#    'acudir',
#    'especificar',
#    'iniciar',
#    'inmediato',
#    'efectivo',
#    'adecuar',
#    'examen',
#    'voluntario',
#    'seguro',
#    'situacion',
#    'apropiar',
#    'interrupcion',
#    'descartar',
#    'adicionalmente',
#    'abortar',
#    'correcto']},
#  {'word': 'medicamento',
#   'child': ['disminuir',
#    'iniciar',
#    'secundario',
#    'implantar',
#    'subdermico',
#    'mes',
#    'efectivo',
#    'tomar',
#    'regular',
#    'mesar',
#    'efectividad',
#    'dispositivo',
#    'hormona',
#    'recomendar',
#    'diu',
#    'semana',
#    'correcto',
#    'duracion',
#    'probar',
#    'casar']},
#  {'word': 'solicitar',
#   'child': ['eps',
#    'recibir',
#    'atencion',
#    'consultar',
#    'dudar',
#    'poder',
#    'medicar',
#    'gratuito',
#    'asesorar',
#    'centrar',
#    'asesoria',
#    'garantizar',
#    'especificar',
#    'salud',
#    'valoracion',
#    'adecuar',
#    'necesidad',
#    'recomer',
#    'requerir',
#    'recomendar']},
#  {'word': 'recomendar',
#   'child': ['efectivo',
#    'requerir',
#    'adecuar',
#    'mesar',
#    'iniciar',
#    'embarazo',
#    'prevencion',
#    'descartar',
#    'correcto',
#    'inmediato',
#    'especificar',
#    'duracion',
#    'examen',
#    'adicionalmente',
#    'acudir',
#    'planear',
#    'empacar',
#    'probar',
#    'mes',
#    'apropiar']},
#  {'word': 'hijo',
#   'child': ['edad',
#    'responsable',
#    'adolescente',
#    'madre',
#    'humano',
#    'ley',
#    'colombiano',
#    'fundamental',
#    'apoyar',
#    'legal',
#    'social',
#    'delito',
#    'bogota',
#    'familiar',
#    'librar',
#    'discapacidad',
#    'decisión',
#    'denunciar',
#    'acceso',
#    'incluir']},
#  {'word': 'contactar',
#   'child': ['piel',
#    'genital',
#    'relacion',
#    'lubricacion',
#    'adquirir',
#    'placentero',
#    'lesionar',
#    'transmitir',
#    'significar',
#    'estimular',
#    'actividad',
#    'inflamacion',
#    'doloroso',
#    'malo',
#    'estimulacion',
#    'presion',
#    'posibilidad',
#    'conocer',
#    'vaginal',
#    'referir']},
#  {'word': 'efectividad',
#   'child': ['tomar',
#    'regular',
#    'implantar',
#    'medicamento',
#    'hormonal',
#    'metodo',
#    'efecto',
#    'embarazar',
#    'disminuir',
#    'emergencia',
#    'pildora',
#    'subdermico',
#    'iniciar',
#    'intrauterino',
#    'secundario',
#    'menstruacion',
#    'efectivo',
#    'diu',
#    'mes',
#    'dispositivo']},
#  {'word': 'centrar',
#   'child': ['atencion',
#    'salud',
#    'asesoria',
#    'recomer',
#    'recibir',
#    'solicitar',
#    'consultar',
#    'dudar',
#    'eps',
#    'medicar',
#    'asistir',
#    'valoracion',
#    'asesorar',
#    'poder',
#    'prevenir',
#    'citar',
#    'gratuito',
#    'anticoncepcion',
#    'especificar',
#    'necesidad']},
#  {'word': 'disminuir',
#   'child': ['mes',
#    'subdermico',
#    'secundario',
#    'dispositivo',
#    'efectivo',
#    'iniciar',
#    'medicamento',
#    'duracion',
#    'diu',
#    'hormona',
#    'correcto',
#    'semana',
#    'implantar',
#    'intrauterino',
#    'mesar',
#    'regular',
#    'recomendar',
#    'largo',
#    'empacar',
#    'inmediato']},
#  {'word': 'placer',
#   'child': ['practicar',
#    'gustar',
#    'excitacion',
#    'masturbacion',
#    'relacion',
#    'orgasmo',
#    'placentero',
#    'disfrutar',
#    'estimulacion',
#    'parejo',
#    'identificar',
#    'penetracion',
#    'malo',
#    'significar',
#    'normal',
#    'sexualidad',
#    'conocer',
#    'actividad',
#    'cuerpo',
#    'penar']},
#  {'word': 'colombia',
#   'child': ['ley',
#    'social',
#    'fundamental',
#    'legal',
#    'librar',
#    'denunciar',
#    'edad',
#    'victimar',
#    'decisión',
#    'discapacidad',
#    'apoyar',
#    'linear',
#    'temer',
#    'delito',
#    'cortar',
#    'incluir',
#    'ser',
#    'reproductivo',
#    'voluntario',
#    'ejercicio']},
#  {'word': 'anal',
#   'child': ['genital',
#    'penetracion',
#    'practicar',
#    'parejo',
#    'vaginal',
#    'contactar',
#    'relacion',
#    'placer',
#    'excitacion',
#    'lubricacion',
#    'penar',
#    'oral',
#    'gustar',
#    'sexual',
#    'relacionar',
#    'semen',
#    'placentero',
#    'masturbacion',
#    'piel',
#    'estimulacion']},
#  {'word': 'eps',
#   'child': ['solicitar',
#    'consultar',
#    'recibir',
#    'dudar',
#    'poder',
#    'gratuito',
#    'garantizar',
#    'atencion',
#    'medicar',
#    'especificar',
#    'asesorar',
#    'adecuar',
#    'requerir',
#    'acudir',
#    'abortar',
#    'siguiente',
#    'recomendar',
#    'valorar',
#    'valoracion',
#    'necesidad']},
#  {'word': 'resultar',
#   'child': ['caso',
#    'comunicacion',
#    'presion',
#    'malo',
#    'definir',
#    'conocer',
#    'actividad',
#    'estimular',
#    'emocional',
#    'ocasionar',
#    'identificar',
#    'diferenciar',
#    'fisico',
#    'estr',
#    'significar',
#    'consentimiento',
#    'obtener',
#    'estimulacion',
#    'algun',
#    'gustar']},
#  {'word': 'victimar',
#   'child': ['violencia',
#    'ley',
#    'colombia',
#    'denunciar',
#    'delito',
#    'social',
#    'discapacidad',
#    'acto',
#    'legal',
#    'librar',
#    'edad',
#    'querer',
#    'apoyar',
#    'fundamental',
#    'abusar',
#    'consentimiento',
#    'decisión',
#    'establecer',
#    'linear',
#    'incluir']},
#  {'word': 'temer',
#   'child': ['linear',
#    'bogota',
#    'comunicarte',
#    'social',
#    'apoyar',
#    'denunciar',
#    'librar',
#    'ley',
#    'legal',
#    'edad',
#    'fundamental',
#    'adolescente',
#    'acceso',
#    'discapacidad',
#    'medicinar',
#    'ser',
#    'cortar',
#    'colombia',
#    'colombiano',
#    'ayudar']},
#  {'word': 'orgasmo',
#   'child': ['excitacion',
#    'estimulacion',
#    'normal',
#    'placentero',
#    'eyaculacion',
#    'placer',
#    'semen',
#    'masturbacion',
#    'femenino',
#    'gustar',
#    'conocer',
#    'eyacular',
#    'relacion',
#    'resultar',
#    'liquidar',
#    'ereccion',
#    'malo',
#    'estimular',
#    'lubricacion',
#    'practicar']},
#  {'word': 'incluir',
#   'child': ['establecer',
#    'ser',
#    'ejercer',
#    'librar',
#    'ejercicio',
#    'apoyar',
#    'humano',
#    'bienestar',
#    'delito',
#    'emocional',
#    'ayudar',
#    'decisión',
#    'condicion',
#    'pornografia',
#    'condicionar',
#    'fisica',
#    'compartir',
#    'definir',
#    'implicar',
#    'colombiano']},
#  {'word': 'masturbacion',
#   'child': ['placentero',
#    'cuerpo',
#    'estimulacion',
#    'placer',
#    'relacion',
#    'orgasmo',
#    'penetracion',
#    'malo',
#    'conocer',
#    'actividad',
#    'ereccion',
#    'significar',
#    'virginidad',
#    'himen',
#    'zona',
#    'excitacion',
#    'experimentar',
#    'virgen',
#    'estimular',
#    'normal']},
#  {'word': 'dudar',
#   'child': ['gratuito',
#    'eps',
#    'consultar',
#    'recibir',
#    'asesorar',
#    'solicitar',
#    'medicar',
#    'garantizar',
#    'adecuar',
#    'poder',
#    'especificar',
#    'atencion',
#    'necesidad',
#    'recomendar',
#    'requerir',
#    'valorar',
#    'embarazo',
#    'acudir',
#    'prevencion',
#    'regular']},
#  {'word': 'periodo',
#   'child': ['hormona',
#    'menstruacion',
#    'secundario',
#    'ovulo',
#    'dispositivo',
#    'diu',
#    'intrauterino',
#    'disminuir',
#    'mes',
#    'semana',
#    'subdermico',
#    'retrasar',
#    'alteración',
#    'espermatozoide',
#    'duracion',
#    'utero',
#    'bajo',
#    'probabilidad',
#    'efecto',
#    'alterar']},
#  {'word': 'especificar',
#   'child': ['requerir',
#    'acudir',
#    'adecuar',
#    'recomendar',
#    'poder',
#    'medicar',
#    'mesar',
#    'descartar',
#    'examen',
#    'apropiar',
#    'situacion',
#    'probar',
#    'inmediato',
#    'adicionalmente',
#    'garantizar',
#    'seguro',
#    'voluntario',
#    'embarazo',
#    'casar',
#    'manejar']},
#  {'word': 'abortar',
#   'child': ['interrupcion',
#    'voluntario',
#    'garantizar',
#    'acudir',
#    'legal',
#    'social',
#    'inmediato',
#    'fundamental',
#    'requerir',
#    'situacion',
#    'cortar',
#    'acceso',
#    'especificar',
#    'probar',
#    'seguro',
#    'decisión',
#    'beneficio',
#    'denunciar',
#    'medicinar',
#    'mesar']}]

# %%
queries_plain = []
for word_main in ret:
    for word_two in word_main['child']:
        queries_plain.append("{} AND {}".format(word_main['word'], word_two))

# %%
queries_df = pd.DataFrame(queries_plain)

# %%
with open("queries_bytes.pkl", "wb") as queries_outfile:
    pickle.dump(queries_plain, queries_outfile)

# %%
common_words
# Out:
# [('sexual', 2462),
#  ('relacionar', 931),
#  ('personar', 858),
#  ('salud', 759),
#  ('embarazar', 703),
#  ('condon', 665),
#  ('anticonceptivo', 633),
#  ('infección', 627),
#  ('poder', 596),
#  ('transmision', 575),
#  ('asistir', 525),
#  ('parejo', 498),
#  ('recomer', 473),
#  ('anticoncepcion', 433),
#  ('consultar', 395),
#  ('ano', 356),
#  ('sentir', 349),
#  ('relacion', 343),
#  ('casar', 342),
#  ('tomar', 304),
#  ('informacion', 299),
#  ('presentar', 295),
#  ('sexo', 278),
#  ('derecho', 273),
#  ('página', 270),
#  ('medicar', 252),
#  ('penar', 252),
#  ('causar', 245),
#  ('citar', 243),
#  ('infeccion', 243),
#  ('genital', 240),
#  ('desear', 233),
#  ('sangrar', 232),
#  ('tipo', 225),
#  ('dolor', 221),
#  ('recibir', 214),
#  ('sexualidad', 214),
#  ('adecuar', 213),
#  ('prevenir', 209),
#  ('querer', 205),
#  ('normal', 203),
#  ('vaginal', 201),
#  ('entidad', 200),
#  ('edad', 196),
#  ('atencion', 193),
#  ('hormonal', 185),
#  ('practicar', 184),
#  ('metodo', 180),
#  ('vida', 178),
#  ('asesoria', 177),
#  ('pastilla', 177),
#  ('oral', 176),
#  ('iniciar', 174),
#  ('vagina', 171),
#  ('menstrual', 167),
#  ('cuerpo', 163),
#  ('efecto', 160),
#  ('vih', 160),
#  ('enfermedad', 158),
#  ('menstruacion', 157),
#  ('sexperto', 149),
#  ('segundo', 147),
#  ('problema', 147),
#  ('sintoma', 138),
#  ('emergencia', 137),
#  ('eyaculacion', 128),
#  ('orientacion', 128),
#  ('violencia', 126),
#  ('ayudar', 123),
#  ('encontrar', 121),
#  ('siguiente', 119),
#  ('caso', 119),
#  ('reproductivo', 118),
#  ('necesidad', 112),
#  ('femenino', 112),
#  ('penetracion', 111),
#  ('proteger', 111),
#  ('probar', 109),
#  ('medicamento', 108),
#  ('solicitar', 108),
#  ('recomendar', 107),
#  ('hijo', 106),
#  ('contactar', 104),
#  ('efectividad', 103),
#  ('centrar', 102),
#  ('disminuir', 101),
#  ('placer', 101),
#  ('colombia', 100),
#  ('anal', 100),
#  ('eps', 99),
#  ('resultar', 98),
#  ('victimar', 98),
#  ('temer', 97),
#  ('orgasmo', 97),
#  ('incluir', 96),
#  ('masturbacion', 96),
#  ('dudar', 95),
#  ('periodo', 94),
#  ('especificar', 94),
#  ('abortar', 94)]

# %%
set([1,2])

# %% [markdown]
# ## another way

# %%
def arbol_build(child, yap, n=2):
    if n <= 0:
        return [{"name": son["name"], "children": [{"name":item[0]} for item in model.wv.most_similar(son["name"], topn=15) if item[0] not in yap]} for son in child]
    else:
        return [{"name": son["name"], "children": arbol_build([{"name":item[0]} for item in model.wv.most_similar(son["name"], topn=10)  if item[0] not in yap], yap + [son["name"]] + [item[0] for item in model.wv.most_similar(son["name"], topn=15)  if item[0] not in yap], n-1)} for son in child]

# %%
dic = {'name': 'embarazo'}
dic["children"] = [{"name":item[0]} for item in model.wv.most_similar(dic["name"], topn=15)]
dic["children"] = arbol_build(dic["children"], ['embarazo'] + [{"name":item[0]} for item in model.wv.most_similar(dic["name"], topn=10) if item[0] not in ['embarazo']] , 2)

# %%
json.dumps(dic)

# %% [markdown]
# # Getting Queries

# %%
def getQueries(dic, acum): 
    if "children" not in [attr for attr in dic]:
        if len(acum) > 0:
            return " AND ".join([acum, dic["name"]])
        else:
            return dic["name"]
    else:
        if len(acum) > 0:
            return " ; ".join([" AND ".join([acum, dic["name"]])] + [getQueries(d, "{} AND {}".format(acum, dic["name"])) for d in dic["children"]])
        else:
            return " ; ".join([getQueries(d, dic["name"]) for d in dic["children"]])

# %%
queries = getQueries(ret, "")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-733da5b79c8d> in <module>
# ----> 1 queries = getQueries(ret, "")
#
# <ipython-input-86-eece76f2cad2> in getQueries(dic, acum)
#       4             return " AND ".join([acum, dic["name"]])
#       5         else:
# ----> 6             return dic["name"]
#       7     else:
#       8         if len(acum) > 0:
#
# TypeError: list indices must be integers or slices, not str

# %%
bigQueries = [" AND ".join(sorted(("".join(qq.split(" "))).split("AND"))) for qq in [q for q in queries.split(";")]]
len(bigQueries)

# %%
nQueries = list(set(bigQueries))
nQueries.sort(key=len)
len(nQueries)

# %%
[qr for qr in nQueries if "anticoncepcion" in qr]

# %%
import pickle
with open("bigQueryList3.pkl", 'wb') as fiout:
    pickle.dump(nQueries, fiout)

# %% [markdown]
# ### read pickle

# %%
import pickle
with open("bigQueryList3.pkl", 'rb') as fiin:
    queries = pickle.load(fiin)

# %%
len(queries)

# %%
sorted([qr for qr in queries if "anticoncepcion" in qr], key=len)

# %% [markdown]
# # Lab for synonims

# %%
nlp_lg = spacy.load("es_core_news_md")

# %%
vector = nlp(u"Fruta").vector
nlp_lg.vocab.vectors.most_similar(nlp_lg.vocab['fruta'].vector.reshape(1,50))

# %%
nlp_lg.vocab['fruta']

# %%
def most_similar(word, topn=5):
    word = nlp_lg.vocab[str(word)]
    queries = [
      w for w in word.vocab 
      if w.is_lower == word.is_lower and w.prob >= -15 and np.count_nonzero(w.vector)
    ]

    by_similarity = sorted(queries, key=lambda w: word.similarity(w), reverse=True)
    return [(w.lower_,w.similarity(word)) for w in by_similarity[:topn+1] if w.lower_ != word.lower_]

# %%
most_similar("embarazo", topn=10)

# %%
import time
'twitterscraper "{}" -o {}.json -p'.format("213123", "-".join(['123123']))
